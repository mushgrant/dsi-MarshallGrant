# %%
import requests
import bs4 
from bs4 import BeautifulSoup

# %%
url = "http://www.indeed.com/jobs?q=Data+Scientist&l=Atlanta%2C+GA"

# %%
r = requests.get(url)

# %%
print r
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(r.content)
# Out:
# //anaconda/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file //anaconda/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
soup
# Out:
# <!DOCTYPE html>\n<html lang="en">\n<head>\n<meta content="text/html;charset=unicode-escape" http-equiv="content-type"/>\n<!-- pll --><script type="text/javascript">\n\n(function ( tk ) { if ( tk && document.images ) { var s="/", q="?", a="&", e="="; (new Image()).src = s+"rpc"+s+"log"+q+"a"+e+"jslat"+a+"tk"+e+tk; } })('1b1pgpoona4clbpa');\n</script>\n<script src="/s/2c2181b/en_US.js" type="text/javascript"></script>\n<link href="/s/1a7c741/jobsearch_all.css" rel="stylesheet" type="text/css"/>\n<link href="http://rss.indeed.com/rss?q=Data+Scientist&amp;l=Atlanta%2C+GA" rel="alternate" title="Data Scientist Jobs, Employment in Atlanta, GA" type="application/rss+xml"/>\n<link href="/m/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA" media="handheld" rel="alternate"/>\n<script type="text/javascript">\n    \n    window['closureReadyCallbacks'] = [];\n\n    function call_when_jsall_loaded(cb) {\n        if (window['closureReady']) {\n            cb();\n        } else {\n            window['closureReadyCallbacks'].push(cb);\n        }\n    }\n</script>\n<script src="/s/9dbde1e/jobsearch-all-compiled.js" type="text/javascript"></script>\n<script type="text/javascript">\nvar pingUrlsForGA = [];\n\nvar searchUID = '1b1pgpoona4clbpa';\nvar tk = '1b1pgpoona4clbpa';\n\nvar loggedIn = false;\nvar myindeed = true;\nvar userEmail = '';\nvar tellFriendEmail = '';\nvar globalLoginURL = 'http:\\/\\/www.indeed.com\\/account\\/login?dest=%2Fq-Data-Scientist-l-Atlanta%2C-GA-jobs.html';\nvar globalRegisterURL = 'http:\\/\\/www.indeed.com\\/account\\/register?dest=%2Fq-Data-Scientist-l-Atlanta%2C-GA-jobs.html';\nvar searchKey = 'a9b405443ccf34fa';\nvar searchState = 'q=Data+Scientist&amp;l=Atlanta%2C+GA';\nvar searchQS = 'q=Data+Scientist&l=Atlanta,+GA';\nvar eventType = 'jobsearch';\nvar locale = 'en_US';\nfunction clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1b1pgpoona4clbpa&jsa=4231'; a.href = jsh; }\nfunction sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }\nfunction sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }\nfunction ptk(st,p) {document.cookie = 'PTK="tk=1b1pgpoona4clbpa&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}\nfunction rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}\n</script>\n<script type="text/javascript">\nfunction loadJSAsync( ) {\nfor ( var i = 0; i < arguments.length; i++ ) {\nvar url = arguments[i];\n(function() {\nvar s = document.createElement("script"), el = document.getElementsByTagName("script")[0];\ns.async = true;\ns.src = url;\nel.parentNode.insertBefore(s, el);\n})();\n}\n}\n</script>\n<meta content="356  Data Scientist Jobs available in Atlanta, GA on Indeed.com.  one search.  all jobs." name="description"/>\n<meta content="Data Scientist Jobs, Employment in Atlanta, GA, Atlanta, GA careers, Atlanta, GA employment, Atlanta, GA job listings, Atlanta, GA job search, Atlanta, GA search engine, work in Atlanta, GA" name="keywords"/>\n<link href="/q-Data-Scientist-l-Atlanta,-GA-jobs.html" rel="canonical"/><link href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=10" rel="next"/><style type="text/css">\n#recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }\n#recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }\n</style>\n<script type="text/javascript">\nvar indeedCsrfToken = 'bvzTcNC6RkV1fySQCLPoKv7AfrkaOVhI';\nvar hashedCsrfToken = '31e423491b5a1fc8cb5d48385b303fd1';\n</script>\n<style type="text/css">\n.jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{font-family:"Fira Sans", sans-serif !important}.jasxcustomfonttst-useGibson *{font-family:"Gibson", sans-serif !important}\n< ...

# %%
print soup.prettify() # you have to print it to make it prettify
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html;charset=utf-8" http-equiv="content-type"/>
#   <!-- pll -->
#   <script type="text/javascript">
#    (function ( tk ) { if ( tk && document.images ) { var s="/", q="?", a="&", e="="; (new Image()).src = s+"rpc"+s+"log"+q+"a"+e+"jslat"+a+"tk"+e+tk; } })('1b1pgpoona4clbpa');
#   </script>
#   <script src="/s/2c2181b/en_US.js" type="text/javascript">
#   </script>
#   <link href="/s/1a7c741/jobsearch_all.css" rel="stylesheet" type="text/css"/>
#   <link href="http://rss.indeed.com/rss?q=Data+Scientist&amp;l=Atlanta%2C+GA" rel="alternate" title="Data Scientist Jobs, Employment in Atlanta, GA" type="application/rss+xml"/>
#   <link href="/m/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA" media="handheld" rel="alternate"/>
#   <script type="text/javascript">
#    window['closureReadyCallbacks'] = [];
#
#     function call_when_jsall_loaded(cb) {
#         if (window['closureReady']) {
#             cb();
#         } else {
#             window['closureReadyCallbacks'].push(cb);
#         }
#     }
#   </script>
#   <script src="/s/9dbde1e/jobsearch-all-compiled.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var pingUrlsForGA = [];
#
# var searchUID = '1b1pgpoona4clbpa';
# var tk = '1b1pgpoona4clbpa';
#
# var loggedIn = false;
# var myindeed = true;
# var userEmail = '';
# var tellFriendEmail = '';
# var globalLoginURL = 'http:\/\/www.indeed.com\/account\/login?dest=%2Fq-Data-Scientist-l-Atlanta%2C-GA-jobs.html';
# var globalRegisterURL = 'http:\/\/www.indeed.com\/account\/register?dest=%2Fq-Data-Scientist-l-Atlanta%2C-GA-jobs.html';
# var searchKey = 'a9b405443ccf34fa';
# var searchState = 'q=Data+Scientist&amp;l=Atlanta%2C+GA';
# var searchQS = 'q=Data+Scientist&l=Atlanta,+GA';
# var eventType = 'jobsearch';
# var locale = 'en_US';
# function clk(id) { var a = document.getElementById(id); var hr = a.href; var si = a.href.indexOf('&jsa='); if (si > 0) return; var jsh = hr + '&tk=1b1pgpoona4clbpa&jsa=4231'; a.href = jsh; }
# function sjomd(id) { var a = document.getElementById(id); var hr = a.href; var ocs = hr.indexOf('&oc=1'); if (ocs < 0) return; var oce = ocs + 5; a.href = hr.substring(0, ocs) + hr.substring(oce); }
# function sjoc(id, sal) { var a = document.getElementById(id); a.href = a.href + '&oc=1&sal='+sal; }
# function ptk(st,p) {document.cookie = 'PTK="tk=1b1pgpoona4clbpa&type=jobsearch&subtype='+st+(p?'&'+p:'')+'"; path=/';}
# function rbptk(st, c, p) { ptk(st, 'cat='+c+(p?'&p='+p:''));}
#   </script>
#   <script type="text/javascript">
#    function loadJSAsync( ) {
# for ( var i = 0; i < arguments.length; i++ ) {
# var url = arguments[i];
# (function() {
# var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
# s.async = true;
# s.src = url;
# el.parentNode.insertBefore(s, el);
# })();
# }
# }
#   </script>
#   <meta content="356  Data Scientist Jobs available in Atlanta, GA on Indeed.com.  one search.  all jobs." name="description"/>
#   <meta content="Data Scientist Jobs, Employment in Atlanta, GA, Atlanta, GA careers, Atlanta, GA employment, Atlanta, GA job listings, Atlanta, GA job search, Atlanta, GA search engine, work in Atlanta, GA" name="keywords"/>
#   <link href="/q-Data-Scientist-l-Atlanta,-GA-jobs.html" rel="canonical"/>
#   <link href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=10" rel="next"/>
#   <style type="text/css">
#    #recPromoDisplay { margin-bottom: 3em;margin-left: 0.5em; }
# #recPromoDisplayPageLast { font-size: 16px; margin: 1.5em 0; }
#   </style>
#   <script type="text/javascript">
#    var indeedCsrfToken = 'bvzTcNC6RkV1fySQCLPoKv7AfrkaOVhI';
# var hashedCsrfToken = '31e423491b5a1fc8cb5d48385b303fd1';
#   </script>
#   <style type="text/css">
#    .jasxcustomfonttst-useCustomHostedFontFullPage *{font-family:"Open Sans", sans-serif !important}.jasxcustomfonttst-useLato *{font-family:"Lato", sans-serif !important}.jasxcustomfonttst-useFira *{font-family:"Fira Sans", sans-serif !important}.jasxcustomfonttst-useGibson *{font-family:"Gibson", sans-serif !important}
#   </style>
#   <style type="text/css">
#    #resultsCol { padding-top: 0; }
# .searchCount { margin-top: 6px; }
# .showing { padding-top: 9px; padding-bottom: 9px; }
#
# .brdr { height: 1px; overflow: hidden; background-color: #ccc; }
#
# #bjobalerts { margin-top: 0; }
#
# /* Tall window sizes */
# @media only screen and (min-height:780px){
# .showing { padding-bottom: 0; }
# }
#
# /* Wide window sizes */
# @media only screen and (min-width:1125px){
# .brdr  { margin-left: 12px; margin-right: 12px; }
# }
#
# a,a:link,.link,.btn,.btn:hover{text-decoration:none}a:hover,.link:hover{text-decoration:underline}.dya-container a{text-decoration:underline !important}
#   </style>
#   <script>
#    function onLoadHandler() {
#
# document.js.reset();
# jobSeenInit('1b1pgpoona4clbpa');
#
# if ( document.radius_update ) { document.radius_update.reset(); }
#
# }
#
# initLogInitialUserInteraction('1b1pgpoona4clbpa', 'serp');
#
# window.onload = onLoadHandler;
#   </script>
#   <link href="android-app://com.indeed.android.jobsearch/http/www.indeed.com/m/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA" rel="alternate"/>
#   <title>
#    Data Scientist Jobs, Employment in Atlanta, GA
# |
# Indeed.com
#   </title>
#   <style type="text/css">
#    .btn,.sg-btn{display:inline-block;padding:9px 15px;border:1px solid #9a99ac;border-bottom-color:#a2a2a2;-webkit-border-radius:6px;-moz-border-radius:6px;-ms-border-radius:6px;-o-border-radius:6px;border-radius:6px;background-color:#D9D9E2;background-image:-moz-linear-gradient(top, #f8f8f9, #D9D9E2);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#f8f8f9), to(#D9D9E2));background-image:-webkit-linear-gradient(top, #f8f8f9, #D9D9E2);background-image:linear-gradient(to bottom, #f8f8f9, #D9D9E2);background-repeat:repeat-x;-webkit-box-shadow:0 1px 5px rgba(0,0,0,0.2);-moz-box-shadow:0 1px 5px rgba(0,0,0,0.2);-ms-box-shadow:0 1px 5px rgba(0,0,0,0.2);-o-box-shadow:0 1px 5px rgba(0,0,0,0.2);box-shadow:0 1px 5px rgba(0,0,0,0.2);color:#333;vertical-align:middle;text-align:center;text-decoration:none;text-shadow:0 1px #fff;font-weight:700;font-size:16px;font-family:"Helvetica Neue",Helvetica,Arial,"Lucida Grande",sans-serif;line-height:22px;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#fff8f8f9', endColorstr='#ffe6e6e6', GradientType=0);cursor:pointer;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;-webkit-touch-callout:none;-webkit-highlight:none;-webkit-tap-highlight-color:transparent;text-overflow:ellipsis;white-space:nowrap;overflow:hidden}.btn.active,.btn.sg-active,.btn:active,.btn.disabled,.btn.sg-disabled,.btn[disabled],.sg-btn.active,.sg-btn.sg-active,.sg-btn:active,.sg-btn.disabled,.sg-btn.sg-disabled,.sg-btn[disabled]{outline:none;background-color:#f8f8f9;color:#333}.btn:focus,.sg-btn:focus{outline:0;box-shadow:0 0 1px 0 #1642bb;-webkit-transition:box-shadow 0.2s linear;-moz-transition:box-shadow 0.2s linear;transition:box-shadow 0.2s linear}.btn.active,.btn.sg-active,.btn:active,.sg-btn.active,.sg-btn.sg-active,.sg-btn:active{background-color:#f8f8f9;background-image:none;-webkit-box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05);-moz-box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05);box-shadow:inset 0 2px 4px rgba(0,0,0,0.15),0 1px 2px rgba(0,0,0,0.05)}.btn.disabled,.btn.sg-disabled,.btn[disabled],.sg-btn.disabled,.sg-btn.sg-disabled,.sg-btn[disabled]{background-color:#f8f8f9;background-image:none;-webkit-box-shadow:none;-moz-box-shadow:none;box-shadow:none;opacity:.65;filter:alpha(opacity=65);cursor:default}.btn-primary,.sg-btn-primary{border-color:#1642bb;background-color:#5585f2;background-image:-moz-linear-gradient(top, #6598ff, #2e5ad7);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#6598ff), to(#2e5ad7));background-image:-webkit-linear-gradient(top, #6598ff, #2e5ad7);background-image:linear-gradient(to bottom, #6598ff, #2e5ad7);background-repeat:repeat-x;color:#F8F8F9;text-shadow:0 -1px #0f2299;-ms-filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2299, Positive=true);filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f2299, Positive=true);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#ff6598fe', endColorstr='#ff3c69e0', GradientType=0);zoom:1}.btn-primary.active,.btn-primary.sg-active,.btn-primary:active,.btn-primary.disabled,.btn-primary.sg-disabled,.btn-primary[disabled],.sg-btn-primary.active,.sg-btn-primary.sg-active,.sg-btn-primary:active,.sg-btn-primary.disabled,.sg-btn-primary.sg-disabled,.sg-btn-primary[disabled]{background-color:#2e5ad7;color:#F8F8F9}.btn-primary:focus,.sg-btn-primary:focus{box-shadow:0 0 1px 0 #000}.btn-special,.sg-btn-special{border-color:#ba3200;background-color:#5585f2;background-image:-moz-linear-gradient(top, #f60, #f14200);background-image:-webkit-gradient(linear, 0 0, 0 100%, from(#f60), to(#f14200));background-image:-webkit-linear-gradient(top, #f60, #f14200);background-image:linear-gradient(to bottom, #f60, #f14200);background-repeat:repeat-x;color:#F8F8F9;text-shadow:0 -1px #000;-ms-filter:progid:DXImageTransform.Microsoft.dropshadow(OffX=0, OffY=-1, Color=#e80f22 ...
#   </style>
#  </head>
#  <body class="ltr jasxcustomfonttst-inactive" data-tn-application="jasx" data-tn-olth="9d2bcadf63a72746e920e0ea88bc9d14" data-tn-originlogid="1b1pgpoona4clbpa" data-tn-originlogtype="jobsearch">
#   <div id="accessibilityBanner">
#    <span id="accessibilityText">
#     Skip to
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">
#      Job Postings
#     </a>
#     ,
#     <!-- This is translated before reaching this state -->
#     <a class="accessibilityMenu" href="#what" id="skipToSearch">
#      Search
#     </a>
#    </span>
#    <a id="accessibilityClose">
#     Close
#    </a>
#   </div>
#   <link href="/s/36397a3/accessibility.css" rel="stylesheet" type="text/css"/>
#   <script type="text/javascript">
#    createTabBar('1b1pgpoona4clbpa');
#   </script>
#   <style type="text/css">
#    body { margin-top: 0; margin-left: 0; margin-right: 0; padding-top: 0; padding-right: 0; padding-left: 0; }
#
# #g_nav { border-bottom:1px solid #ccc; margin-bottom: 9px; }
#
# #g_nav a,
# #g_nav a:visited { color: #00c; }
#
# .navBi { display: -moz-inline-box; display: inline-block; padding: 9px 12px; margin: 0; list-style-type: none; }
#   </style>
#   <div data-tn-section="globalNav" id="g_nav" role="navigation">
#    <table cellpadding="0" cellspacing="0" width="100%">
#     <tr>
#      <td nowrap="">
#       <style type="text/css">
#        #p_nav a.selected { font-weight: bold; text-decoration:none; color: #000 !important; }
#       </style>
#       <div id="p_nav">
#        <span class="navBi">
#         <a class="selected" href="/" id="jobsLink" title="Jobs">
#          Find Jobs
#         </a>
#        </span>
#        <span class="navBi">
#         <a href="/resumes?isid=find-resumes&amp;ikw=SERPtop&amp;co=US&amp;hl=en" id="rezLink">
#          Find Resumes
#         </a>
#        </span>
#        <span class="navBi">
#         <a href="/hire?hl=en&amp;cc=US" id="empLink" onclick="if ( this.href.match('&amp;isid=employerlink-US-control&amp;ikw=SERPtop') == null ) { this.href += '&amp;isid=employerlink-US-control&amp;ikw=SERPtop' };">
#          Employers / Post Job
#         </a>
#        </span>
#       </div>
#      </td>
#      <td align="right" nowrap="">
#       <style type="text/css">
#        #navpromo a,
# #navpromo a:visited {
# color: #f60;
# }
# .resume-promo .ico {
# background: url("data:image/png;base64,...");width:18px; height:24px; margin-top: -3px;
# vertical-align: middle;
# display: inline-block;
# }
#
# .resume-promo .new-ico {
# background: url("data:image/png;base64,...");
# width:16px;
# height:19px;
# margin-top: -3px;
# display: inline-block;
# vertical-align: middle;
# }
#
#
# #u_nav .login_unconfirmed,
# #u_nav .login_unconfirmed a,
# #u_nav .login_unconfirmed a:visited {
# color: #c00
# }
#
# #u_nav .resume_pending,
# #u_nav .resume_pending a,
# #u_nav .resume_pending a:visited {
# color: #c00
# }
#
# #userOptionsLabel {
# position: relative;
# z-index: 5;
# }
#
# #userOptionsLabel b {
# cursor: pointer;
# text-decoration: underline;
# position: relative;
# z-index: 5;
# }
#
# #userOptionsLabel:active {
# outline: none;
# }
#
# #userOptionsLabel.active {
# padding: 9px 11px;
# margin-bottom: -1px;
# _margin-bottom: 0px;
# border: 1px solid #ccc;
# border-top: 0;
# }
#
# #userOptionsLabel.active b {
# color: #666;
# }
#
# #userOptionsLabel.active .arrowStub {
# border-width: 0 3px 3px;
# _border-width: 0px 3px 4px;
# border-color: transparent;
# border-bottom-color: #666;
# top: -2px;
# border-style: dashed dashed solid;
# }
#
# #userOptionsLabel.active .halfPxlFix {
# background: #fff;
# bottom: -3px;
# height: 6px;
# left: 0;
# position: absolute;
# right: 0;
# border: 1px solid #fff;
# }
#
# .arrowStub {
# position: relative;
# border-style: solid dashed dashed;
# border-color: transparent;
# border-top-color: #666;
# display: -moz-inline-box;
# display: inline-block;
# font-size: 0;
# height: 0;
# line-height: 0;
# width: 0;
# left: 4px;
# border-width: 3px 3px 0px;
# padding-top: 1px;
# top: -1px;
# }
#
# #userOptions {
# z-index: 2;
# visibility: hidden;
# position: absolute;
# right: 0;
# x_right: -1px;
# top: 100%;
# padding: 9px 15px;
# border: 1px solid #ccc;
# background: #fff;
# min-width: 150px;
# _width: 150px;
# text-align: left;
# }
#
# #userOptions.open {
# visibility: visible;
# }
#
# .userOptionItem {
# margin: 6px 0;
# }
#
# .userOptionItem a {
# white-space: nowrap;
# }
#
# .userOptionGroup {
# border-top: 1px solid #e8e8e8;
# margin-top: 12px;
# }
#
# .userNameRepeat {
# color: #a8a8a8;
# padding-right: 48px;
# font-weight: bold;
# }
#
# .userOptionGroupHeader {
# font-weight: bold;
# margin: 6px 0;
# }
#       </style>
#       <div id="u_nav">
#        <script type="text/javascript">
#         function isUserOptionsOpen() {
# return document.getElementById('userOptions').className === 'open';
# }
#
# function hideUserOptions() {
# destroyKeyboardTrap();
# document.getElementById('userOptions').className = '';
# document.getElementById('userOptionsLabel').className = 'navBi';
# document.getElementById('userOptionsLabel').setAttribute('aria-label', 'open user action drop down menu');
# }
# function toggleUserOptions(e) {
# var options = document.getElementById('userOptions');
# var label = document.getElementById('userOptionsLabel');
# if (isUserOptionsOpen()) {
# hideUserOptions();
# if (!e.keyCode) {
# label.blur();
# }
# } else {
# options.className = 'open';
# label.className = 'navBi active navMenuDropDown';
# label.setAttribute('aria-label', 'close user action drop down menu');
# document.onclick = function() {
# hideUserOptions();
# document.onclick = function() {
# };
# };
# if (e.keyCode && (e.keyCode == 13 || e.keyCode == 32)) {
# var fL = document.getElementById('userOptions').getElementsByTagName('a')[0];
# if (fL) {
# fL.focus();
# }
# }
# else {
# label.blur();
# }
# createKeyboardTrap(document.getElementById('user_actions'), 'navMenuDropDown', hideUserOptions);
# }
# stopPropagation(e);
#
# }
#
#
# function createKeyboardTrap(containingElement, dropdownLinkClass) {
# var dropdownLinks = containingElement.getElementsByClassName(dropdownLinkClass);
# var numLinks = dropdownLinks.length;
#
# document.onkeydown = function(e) {
# if (e.keyCode === 9) {
# if (e.target === dropdownLinks[0] && e.shiftKey) {
# dropdownLinks[numLinks -1].focus();
# e.preventDefault();
# } else if (e.target === dropdownLinks[numLinks -1] && !e.shiftKey) {
# dropdownLinks[0].focus();
# e.preventDefault()
# }
# } else if (e.keyCode === 27) {
# hideUserOptions();
# }
# }
# }
#
# function destroyKeyboardTrap() {
# document.onkeydown = null;
# }
#
# function stopPropagation(e) {
# var e = e || window.event;
# e.stopPropagation ? e.stopPropagation() : e.cancelBubble = true;
# }
#        </script>
#        <script>
#         function regExpEscape(s) {
#     return String(s).replace(/([-()\[\]{}+?*.$\^|,:#<!\\])/g, '\\$1').
#             replace(/\x08/g, '\\x08');
# }
#
#
# function appendParamsOnce(url, params) {
#     var useParams = params.replace(/^(\?|\&)/, '');
#     if (url.match(new RegExp('[\\?|\\&]' + regExpEscape(useParams))) == null) {
#         return url += (url.indexOf('?') > 0 ? '&' : '?' ) + useParams;
#     }
#     return url;
# }
#        </script>
#        <div id="user_actions">
#         <span class="navBi">
#          <span class="resume-promo" id="navpromo">
#           <a href="/promo/resume" onclick="window.location=this.href + '?from=nav&amp;subfrom=rezprmstd&amp;trk.origin=jobsearch&amp;trk.variant=rezprmstd&amp;trk.tk=1b1pgpoona4clbpa'; return false;">
#            Upload your resume
#           </a>
#          </span>
#         </span>
#         <span class="navBi">
#          <a href="http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3DData%2BScientist%26l%3DAtlanta%2C%2BGA" id="userOptionsLabel" rel="nofollow">
#           Sign in
#          </a>
#         </span>
#        </div>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </div>
#   <style type="text/css">
#    .indeedLogo {
# background: url(/images/medium_logo.png) no-repeat;
#
# margin: 8px 0 0 9px;
# border: 0;
# width: 166px;
# height: 64px;
# -webkit-background-size: 155px 43px;
# background-size: 155px 43px;
# }
# @media (-webkit-min-device-pixel-ratio: 2),
# (   min--moz-device-pixel-ratio: 2),
# (     -o-min-device-pixel-ratio: 2/1),
# (        min-device-pixel-ratio: 2),
# (                min-resolution: 192dpi),
# (                min-resolution: 2dppx) {
# .indeedLogo {
# background: url(/images/medium_logo@2x.png) no-repeat;
# -webkit-background-size: 155px 43px;
# background-size: 155px 43px;
# }
# }
# #branding img { border: 0; }
# #jobsearch { margin: 0 }
# .inwrap { border-right: 1px solid #e8e8e8;border-bottom: 1px solid #e8e8e8;display:inline-block; }
# .inwrap input { box-sizing: border-box; margin:0; height: 30px; font-family:Arial,sans-serif;border:1px solid #ccc;border-bottom-color:#aaa;border-right-color:#aaa; -webkit-border-radius: 0; -webkit-appearance: none; }
# .inwrap .input_text { font-size:18px;padding:3px 6px;_margin: -1px 0; }
# .inwrap .input_submit {color:#614041;font-size:15px;height:30px;background: #e8e8e8; padding:3px 9px;cursor:pointer;_padding:3px;}
# .inwrap .input_submit:active { background: #ccc; }
# .lnav  {width:100%;line-height:1;;font-size:10pt;}
# .jsf .label {font-size:12px; line-height:1.2;padding-top:0;color:#aaa;font-weight:normal;white-space:nowrap;padding-right:1.5em}
# .jsf .label label {font-weight:normal}
# .jsf .sl { font-size: 11px; color: #77c; white-space: nowrap; }
# .npb { padding-bottom: 0; color: #f60; text-transform: lowercase;font-weight:bold; }
# .npl { padding-left: 0 }
# iframe { display:block; }
# .acd { border: 1px solid #333; background: #fff; position:absolute; width:100%; z-index: 1; }
# .aci { font-size: 18px; padding:1px 6px; cursor:pointer; }
# .acis { background:#36c; color:#fff; }
#
# #tjobalerts .ws_label,
# #bjobalerts .ws_label,
# #tjobalerts .member,
# #bjobalerts .member{ z-index: 1; }
# #acr td { padding-top:0; padding-bottom:0; }
# #acr td .h { display:none; }
#
# #what { width: 280px; }
# #where { width: 260px; }
# .inwrapBorder{border:1px solid #1c4ed9;border-top-color:#2f62f1;border-bottom-color:#133fbb;display:inline-block;width:auto}.inwrapBorderTop{border-top:1px solid #69F;display:inline-block;background-color:#3163f2;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#3163F2',endColorstr='#2B57D5');background:-webkit-gradient(linear,left top,left bottom,from(#3163f2),to(#2b57d5));background:-moz-linear-gradient(top,#3163f2,#2b57d5);background:linear-gradient(top,#3163f2,#2b57d5)}.inwrapBorder .input_submit{background:transparent;border:0;color:#fff;font-family:Arial;font-size:15px;margin:0;padding:4px 9px;cursor:pointer;_padding:3px}.inwrapBorder a.input_submit{text-decoration:none;display:block}.inwrapBorder:hover{border-color:#235af6;border-top-color:#4072ff;border-bottom-color:#1e4fd9}.inwrapBorderTop:hover{border-top-color:#7ba7ff;background-color:#4273ff;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#4273ff',endColorstr='#3364f1');background:-webkit-gradient(linear,left top,left bottom,from(#4273ff),to(#3364f1));background:-moz-linear-gradient(top,#4273ff,#3364f1);background:linear-gradient(top,#4273ff,#3364f1)}.inwrapBorder:active{border-color:#536db7;border-top-color:#4b69c1;border-bottom-color:#3753a6}.inwrapBorder:active .inwrapBorderTop{border-top-color:#6c82c1;background-color:#4b69c1;filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#4b69c1',endColorstr='#3753a6');background:-webkit-gradient(linear,left top,left bottom,from(#4b69c1),to(#3753a6));background:-moz-linear-gradient(top,#4b69c1,#3753a6);background:linear-gradient(top,#4b69c1,#3753a6)}.roundedCorner{display:inline-block;zoom:1;*display:inline;vertical-align:baseline;margin:0 2px;outline:0;cursor:pointer;text-align:center;text-decoration:none;font:15px/100% Arial,Helvetica,sans-serif;padding:.5em 2em .55em;text-shadow:0 1px 1px rgba(0,0,0,.3);-webkit-border-radius:.5em;-moz-border-radius:.5em;border-radius:.5em;-webkit-box-shadow:0 1px 2px rgba(0,0,0,.2);-moz-box-shadow:0 1px 2px rgba(0,0,0,.2);box-shadow:0 1px 2px rgba(0,0,0,.2)}.roundedCorner:hover{text-decoration:none}.roundedCorner:active{position:relative;top:1px}.bigrounded{-webkit-border-radius:2em;-moz-border-radius:2em;border-radius:2em}.medium{font-size:12px;padding:.4em 1.5em .42em}.small{font-size:11px;padding:.2em 1em .275em}.indeedblue{color:#d9eef7;border:solid 1px #1c4ed9;background:#3163f2;background:-webkit-gradient(linear,left top,left bottom,from(#2f62f1),to(#133fbb));background:-moz-linear-gradient(top,#2f62f1,#133fbb);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#2F62F1',endColorstr='#133FBB')}.indeedblue:hover,.indeedblue:focus{background:#235af6;background:-webkit-gradient(linear,left top,left bottom,from(#4072ff),to(#1e4fd9));background:-moz-linear-gradient(top,#4072ff,#1e4fd9);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#4072ff',endColorstr='#1e4fd9')}.indeedblue:active{color:#d9eef7;background:-webkit-gradient(linear,left top,left bottom,from(#4b69c1),to(#3753a6));background:-moz-linear-gradient(top,#4b69c1,#3753a6);filter:progid:DXImageTransform.Microsoft.gradient(startColorstr='#4b69c1',endColorstr='#3753a6')}
#   </style>
#   <span id="hidden_colon" style="display:none">
#    :
#   </span>
#   <table border="0" cellpadding="0" cellspacing="0" role="banner">
#    <tr>
#     <td width="1125">
#      <table cellpadding="0" cellspacing="0" class="lnav">
#       <tr>
#        <td id="branding-td" style="vertical-align:top;">
#         <a href="/" id="branding" onmousedown="ptk('logo');">
#          <img alt="one search. all jobs. Indeed" class="indeedLogo" src="..." style="margin-bottom:6px;display:block;" title="one search. all jobs. Indeed"/>
#         </a>
#        </td>
#        <td style="padding-top:3px;" valign="top">
#         <form action="/jobs" class="jsf" id="jobsearch" method="get" name="js" onsubmit="formptk('topsearch','where_ac','',['where_ac','what_ac'], ptk);formptk('topsearch','what_ac','w',['where_ac','what_ac'], ptk);">
#          <table align="left" cellpadding="3" cellspacing="0">
#           <tr>
#            <td class="npb">
#             <label for="what" id="what_label_top">
#              What
#             </label>
#            </td>
#            <td class="npb" colspan="3">
#             <label for="where" id="where_label_top">
#              Where
#             </label>
#            </td>
#           </tr>
#           <tr role="search">
#            <td class="npl epr">
#             <span class="inwrap">
#              <input aria-labelledby="what_label_top hidden_colon what_label" class="input_text" id="what" maxlength="512" name="q" size="31" value="Data Scientist"/>
#             </span>
#             <div style="width:250px">
#              <!-- -->
#             </div>
#            </td>
#            <td class="npl epr">
#             <span class="inwrap">
#              <input aria-labelledby="where_label_top hidden_colon where_label" class="input_text" id="where" maxlength="45" name="l" size="27" value="Atlanta, GA"/>
#             </span>
#             <div style="width:200px">
#              <!-- -->
#             </div>
#            </td>
#            <td class="npl" style="width:1px">
#             <span class="inwrapBorder" style="width:auto;padding-right:0;">
#              <span class="inwrapBorderTop">
#               <input class="input_submit" id="fj" type="submit" value="Find Jobs"/>
#              </span>
#             </span>
#            </td>
#            <td class="npl advanced-search" style="width:240px;">
#             <div style="margin-left:12px; display:flex;">
#              <a class="sl" href="/advanced_search?q=Data+Scientist&amp;l=Atlanta%2C+GA">
#               Advanced Job Search
#              </a>
#             </div>
#            </td>
#           </tr>
#           <tr id="acr">
#            <td>
#             <span class="h">
#             </span>
#            </td>
#            <td class="npl" colspan="2">
#             <div style="position:relative;z-index:2">
#              <div class="acd" id="acdiv" style="display:none;">
#              </div>
#             </div>
#            </td>
#            <td>
#             <span class="h">
#             </span>
#            </td>
#           </tr>
#           <tr id="acr">
#            <td class="npl" colspan="3">
#             <div style="position:relative;z-index:2">
#              <div class="acd" id="what_acdiv" style="display:none;">
#              </div>
#             </div>
#            </td>
#            <td>
#             <span class="h">
#             </span>
#            </td>
#           </tr>
#           <tr valign="baseline">
#            <td class="label" id="what_label_cell">
#             <label aria-hidden="true" for="what" id="what_label">
#              job title, keywords or company
#             </label>
#            </td>
#            <td class="label" colspan="3" id="where_label_cell">
#             <label aria-hidden="true" for="where" id="where_label">
#              city, state, or zip
#             </label>
#            </td>
#           </tr>
#          </table>
#         </form>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#   <script type="text/javascript">
#    initAutocomplete('where_ac', gbid('where'), gbid('acdiv'), '/rpc/suggest?from=serp&tk=1b1pgpoona4clbpa', function() { formptk('topsearch','where_ac', '', ['where_ac','what_ac'], ptk); }, gbid('where'));
#
#         initAutocomplete('what_ac', gbid('what'), gbid('what_acdiv'), '/rpc/suggest?what=true&tk=1b1pgpoona4clbpa', function () {formptk('topsearch', 'what_ac', 'w', ['where_ac','what_ac'], ptk);}, gbid('what'));
#   </script>
#   <script type="text/javascript">
#    function rclk(el,jobdata,oc,sal) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1b1pgpoona4clbpa&from=web&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvFWAZo7EfxiH_m04oz2ySQI5qowR_IR-Ll0C369ESjewTdxZRinduq1bXDPN0fnMz2g1p4QT_ouizF9qKXFgpfeUsD7I0yoL-vL18TWHFZcHFjCvUg-A-sYudHHIglbVUA&ts=1479398974231&sal='+sal+ocstr+'"; path=/'; return true;}
# function zrprclk(el,jobdata,oc) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1b1pgpoona4clbpa&from=reconzrp&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvFWAZo7EfxiH_m04oz2ySQI5qowR_IR-Ll0C369ESjewTdxZRinduq1bXDPN0fnMz2g1p4QT_ouizF9qKXFgpfeUsD7I0yoL-vL18TWHFZcHFjCvUg-A-sYudHHIglbVUA&ts=1479398974231'+ocstr+'"; path=/'; return true;}
# function prjbottomclk(el,jobdata,oc) { var ocstr = oc ? '&onclick=1' : ''; document.cookie='RCLK="jk='+jobdata.jk+'&tk=1b1pgpoona4clbpa&from=reconserp&rd='+jobdata.rd+'&qd=7tdTJLF8oc4dPpT7T_zGvFWAZo7EfxiH_m04oz2ySQI5qowR_IR-Ll0C369ESjewTdxZRinduq1bXDPN0fnMz2g1p4QT_ouizF9qKXFgpfeUsD7I0yoL-vL18TWHFZcHFjCvUg-A-sYudHHIglbVUA&ts=1479398974231'+ocstr+'"; path=/'; return true;}
#
#
# var jobmap = {};
#
# jobmap[0]= {jk:'1a8c086f5f6f1294',efccid: '1122d8f33f5849ff',srcid:'16ba8026d5a02762',cmpid:'e54b646b0aef4211',num:'0',srcname:'Indeed',cmp:'Vision3 Solutions, Inc',cmpesc:'Vision3 Solutions, Inc',cmplnk:'/q-Vision3-Solutions-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Data Scientist- Big Data',locid:'966e6327a98f7e81',rd:'qwCkIAYcCPMCjM7UAT1HUQ'};
#
# jobmap[1]= {jk:'d72c337465398caf',efccid: '2c8951fb90af8949',srcid:'d7ed1711ec9ea451',cmpid:'69e48b1f7c3ce51e',num:'1',srcname:'Indeed',cmp:'FraudScope',cmpesc:'FraudScope',cmplnk:'/q-FraudScope-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Data Scientist',locid:'966e6327a98f7e81',rd:'u7ZhSUZe5IuENH4ORi__Vw'};
#
# jobmap[2]= {jk:'d21cbd39fb6dd414',efccid: '1770b55ff6655ebe',srcid:'d56740668b1dd080',cmpid:'25b5166547bbf543',num:'2',srcname:'AT&amp;T',cmp:'AT&T',cmpesc:'AT&amp;T',cmplnk:'/q-AT&T-l-Atlanta,-GA-jobs.html',loc:'Alpharetta, GA',country:'US',zip:'',city:'Alpharetta',title:'AT&amp;T Professional Data Scientist Alpharetta GA',locid:'136fb7555504878c',rd:'qZbEW5CIRtWoBiKCtAKLFkLRdrSbksHZbrkJY42ldpk'};
#
# jobmap[3]= {jk:'4a4948fe135cb354',efccid: '7062f2e39e3f3a8e',srcid:'24b198b600c19f81',cmpid:'cc35f9c14f8799a9',num:'3',srcname:'ICF International, Inc',cmp:'ICF',cmpesc:'ICF',cmplnk:'/q-ICF-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Scientific Data Analyst',locid:'966e6327a98f7e81',rd:'PAaURojKT6ZqONm8Ax8BWMeDzWLtCZmZLj2Y-bGYlQI'};
#
# jobmap[4]= {jk:'a959ea9503eb0043',efccid: '3e8562386cf03d35',srcid:'62e6f9c57bf35405',cmpid:'11619ce0d3c2c733',num:'4',srcname:'Northrop Grumman',cmp:'Northrop Grumman',cmpesc:'Northrop Grumman',cmplnk:'/q-Northrop-Grumman-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Scientific Data Analyst',locid:'966e6327a98f7e81',rd:'a557iSdFDHifE8KX3ILBwPjl0TZdzt_QvGjJX2Poj_o'};
#
# jobmap[5]= {jk:'cf742a5180d45499',efccid: '58409e11f408a08a',srcid:'6b3b648015ac3a55',cmpid:'ddf188c30da34688',num:'5',srcname:'Infor',cmp:'Infor',cmpesc:'Infor',cmplnk:'/q-Infor-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Sr. Data Scientist',locid:'966e6327a98f7e81',rd:'brH1K70-ipPhhZuRfxbEYPOdlELm80ImBHu0YAxIIf4'};
#
# jobmap[6]= {jk:'ece5708bd668a5e5',efccid: 'c49ca04d9e6ab2f6',srcid:'50e8262be57c4efa',cmpid:'bd2e17bd9d57178b',num:'6',srcname:'IgnitionOne',cmp:'IgnitionOne',cmpesc:'IgnitionOne',cmplnk:'/q-IgnitionOne-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Data Scientist',locid:'966e6327a98f7e81',rd:'uXuodet8lKfk109nykoqIOOeWa-rGiaSNMyWvA9uc2g'};
#
# jobmap[7]= {jk:'01ad090d112dbb83',efccid: '547c358cc3bc5925',srcid:'e2e28e2241cff650',cmpid:'657572328deb01c1',num:'7',srcname:'Indeed',cmp:'Ashton212',cmpesc:'Ashton212',cmplnk:'/q-Ashton212-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Quantitative Analyst | #769',locid:'966e6327a98f7e81',rd:'axcOQxQMYN0a85mP7arLnQ'};
#
# jobmap[8]= {jk:'8b1060b171ddf805',efccid: 'b628be1b6b3919bc',srcid:'12d2c45dfb39d39c',cmpid:'6df24d87c9f05a07',num:'8',srcname:'Macy&#039;s',cmp:'Macy\'s',cmpesc:'Macy&#039;s',cmplnk:'/jobs?q=Macy%27s&l=Atlanta,+GA',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Data Scientist',locid:'966e6327a98f7e81',rd:'WjRP17YOjrNXHzTlrPdpl_rjdLYrAUDN75hTmQv9FDQ'};
#
# jobmap[9]= {jk:'1ae9fbf052162ca0',efccid: '7792a4de321a2f28',srcid:'ab4767fb407a3eea',cmpid:'3e901f592b439cea',num:'9',srcname:'Centers for Disease Control and Prevention',cmp:'Centers for Disease Control and Prevention',cmpesc:'Centers for Disease Control and Prevention',cmplnk:'/q-Centers-for-Disease-Control-and-Prevention-l-Atlanta,-GA-jobs.html',loc:'Atlanta, GA',country:'US',zip:'',city:'Atlanta',title:'Statistician (Health)',locid:'966e6327a98f7e81',rd:'IVfp0CltCVEpHOpKTrwdMU6HTL2YZwzpwYvfeB83wnc'};
#   </script>
#   <style type="text/css">
#    .jobtitle {
# font-weight: bold;
# }
# td.snip b, span.company b, #femp_list .jobtitle, #cmpinfo_list .jobtitle, .jobtitle .new {
# font-weight: normal;
# }
#   </style>
#   <style type="text/css">
#    div.row table tr td.snip { line-height: 1.4; }
#   </style>
#   <table border="0" cellpadding="0" cellspacing="0" id="serpBody" role="main">
#    <tr>
#     <td>
#      <script type="text/javascript">
#       window['ree'] = "pdsssps";
# window['jas'] = "dD1zYXOJR";
#      </script>
#      <style type="text/css">
#       .basePromo{margin-top:8px;margin-bottom:13px;padding-left:12px;padding-right:12px}.redText{color:red}.bold{font-weight:bold}.basePromo.resume{font-size:14px;margin-top:5px}.basePromo.resume>img{height:20px;margin-right:5px;margin-bottom:3px;width:16px}
#      </style>
#      <table border="0" cellpadding="0" cellspacing="0" id="pageContent" width="100%">
#       <tr valign="top">
#        <td data-tn-section="refineBy" id="refineresultscol">
#         <div id="refineresults">
#          <h1>
#           <font size="+1">
#            Data Scientist jobs in Atlanta, GA
#           </font>
#          </h1>
#          <div id="recPromoDisplay" style="display:none;">
#          </div>
#          <script type="text/javascript">
#           call_when_jsall_loaded(function() {
#             var recJobLink = new RecJobLink("Recommended Jobs", "recPromoDisplay", "1b1pgpoksa4cl8m2", "",
#                     "US", "en", "",
#                     "", null, true);
#             recJobLink.onLoad();
#         });
#          </script>
#          <span aria-level="2" role="heading" style="height: 0; overflow: hidden; position: absolute;">
#           Filter results by:
#          </span>
#          <div style="margin-left: 6px; margin-bottom: 1em;">
#           Sort by:
#           <nobr>
#            <b>
#             relevance
#            </b>
#            -
#            <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;sort=date" rel="nofollow">
#             date
#            </a>
#           </nobr>
#          </div>
#          <form action="/jobs" id="radius_update" method="get" name="radius_update">
#           <input name="q" type="hidden" value="Data Scientist"/>
#           <input name="l" type="hidden" value="Atlanta, GA"/>
#           <label for="distance_selector" onclick="this.form.radius.focus();return false;">
#            Distance:
#           </label>
#           <select id="distance_selector" name="radius" onchange="ptk('radius'); this.form.submit();">
#            <option value="0">
#             Exact location only
#            </option>
#            <option value="5">
#             within 5 miles
#            </option>
#            <option value="10">
#             within 10 miles
#            </option>
#            <option value="15">
#             within 15 miles
#            </option>
#            <option selected="" value="25">
#             within 25 miles
#            </option>
#            <option value="50">
#             within 50 miles
#            </option>
#            <option value="100">
#             within 100 miles
#            </option>
#           </select>
#           <noscript>
#            <input id="r_up" name="r_up" type="submit" value="Go"/>
#           </noscript>
#          </form>
#          <div class="rbSection rbOpen" id="rb_Salary Estimate">
#           <div class="rbHeader">
#            <span aria-level="3" class="ws_bold" role="heading">
#             Salary Estimate
#            </span>
#           </div>
#           <div class="rbsrbo" id="SALARY_rbo">
#            <ul class="rbList">
#             <li onmousedown="rbptk('rb', 'salest', '1');">
#              <a href="/q-Data-Scientist-$55,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$55,000+ (298)">
#               $55,000+
#              </a>
#              (298)
#             </li>
#             <li onmousedown="rbptk('rb', 'salest', '2');">
#              <a href="/q-Data-Scientist-$70,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$70,000+ (252)">
#               $70,000+
#              </a>
#              (252)
#             </li>
#             <li onmousedown="rbptk('rb', 'salest', '3');">
#              <a href="/q-Data-Scientist-$85,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$85,000+ (191)">
#               $85,000+
#              </a>
#              (191)
#             </li>
#             <li onmousedown="rbptk('rb', 'salest', '4');">
#              <a href="/q-Data-Scientist-$100,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$100,000+ (125)">
#               $100,000+
#              </a>
#              (125)
#             </li>
#             <li onmousedown="rbptk('rb', 'salest', '5');">
#              <a href="/q-Data-Scientist-$115,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$115,000+ (65)">
#               $115,000+
#              </a>
#              (65)
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="rbSection rbOpen" id="rb_Job Type">
#           <div class="rbHeader">
#            <span aria-level="3" class="ws_bold" role="heading">
#             Job Type
#            </span>
#           </div>
#           <div class="rbsrbo" id="JOB_TYPE_rbo">
#            <ul class="rbList">
#             <li onmousedown="rbptk('rb', 'jobtype', '1');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=fulltime" rel="nofollow" title="Full-time (317)">
#               Full-time
#              </a>
#              (317)
#             </li>
#             <li onmousedown="rbptk('rb', 'jobtype', '2');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=contract" rel="nofollow" title="Contract (23)">
#               Contract
#              </a>
#              (23)
#             </li>
#             <li onmousedown="rbptk('rb', 'jobtype', '3');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=internship" rel="nofollow" title="Internship (10)">
#               Internship
#              </a>
#              (10)
#             </li>
#             <li onmousedown="rbptk('rb', 'jobtype', '4');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=parttime" rel="nofollow" title="Part-time (8)">
#               Part-time
#              </a>
#              (8)
#             </li>
#             <li onmousedown="rbptk('rb', 'jobtype', '5');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=commission" rel="nofollow" title="Commission (2)">
#               Commission
#              </a>
#              (2)
#             </li>
#             <li onmousedown="rbptk('rb', 'jobtype', '6');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=temporary" rel="nofollow" title="Temporary (2)">
#               Temporary
#              </a>
#              (2)
#             </li>
#            </ul>
#           </div>
#          </div>
#          <div class="rbSection rbOpen" id="rb_Location">
#           <div class="rbHeader">
#            <span aria-level="3" class="ws_bold" role="heading">
#             Location
#            </span>
#           </div>
#           <div class="rbsrbo" id="LOCATION_rbo">
#            <ul class="rbList">
#             <li onmousedown="rbptk('rb', 'loc', '1');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Atlanta,+GA&amp;jlid=966e6327a98f7e81" rel="nofollow" title="Atlanta, GA (255)">
#               Atlanta, GA
#              </a>
#              (255)
#             </li>
#             <li onmousedown="rbptk('rb', 'loc', '2');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Alpharetta,+GA&amp;jlid=136fb7555504878c" rel="nofollow" title="Alpharetta, GA (65)">
#               Alpharetta, GA
#              </a>
#              (65)
#             </li>
#             <li onmousedown="rbptk('rb', 'loc', '3');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Duluth,+GA&amp;jlid=ed96b91845c744fe" rel="nofollow" title="Duluth, GA (10)">
#               Duluth, GA
#              </a>
#              (10)
#             </li>
#             <li onmousedown="rbptk('rb', 'loc', '4');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Marietta,+GA&amp;jlid=528fb8dbaacbeb3b" rel="nofollow" title="Marietta, GA (6)">
#               Marietta, GA
#              </a>
#              (6)
#             </li>
#             <li onmousedown="rbptk('rb', 'loc', '5');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Norcross,+GA&amp;jlid=61b742028b096345" rel="nofollow" title="Norcross, GA (4)">
#               Norcross, GA
#              </a>
#              (4)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '6');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Berkeley+Lake,+GA&amp;jlid=1b2f56c7228d460f" rel="nofollow" title="Berkeley Lake, GA (3)">
#               Berkeley Lake, GA
#              </a>
#              (3)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '7');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Johns+Creek,+GA&amp;jlid=b258b190889f0f22" rel="nofollow" title="Johns Creek, GA (3)">
#               Johns Creek, GA
#              </a>
#              (3)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '8');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Decatur,+GA&amp;jlid=f9ba64383bdcdb29" rel="nofollow" title="Decatur, GA (2)">
#               Decatur, GA
#              </a>
#              (2)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '9');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Smyrna,+GA&amp;jlid=254cfc0ab0df7665" rel="nofollow" title="Smyrna, GA (2)">
#               Smyrna, GA
#              </a>
#              (2)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '10');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Stone+Mountain,+GA&amp;jlid=24923703f25e1c15" rel="nofollow" title="Stone Mountain, GA (2)">
#               Stone Mountain, GA
#              </a>
#              (2)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '11');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Roswell,+GA&amp;jlid=abf990a05b719190" rel="nofollow" title="Roswell, GA (2)">
#               Roswell, GA
#              </a>
#              (2)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '12');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Kennesaw,+GA&amp;jlid=382ecefe55e0ce93" rel="nofollow" title="Kennesaw, GA (2)">
#               Kennesaw, GA
#              </a>
#              (2)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'loc', '13');">
#              <a href="/q-Data-Scientist-jobs.html">
#               Data Scientist jobs
#              </a>
#              nationwide
#             </li>
#            </ul>
#            <div class="more_link">
#             <span onclick="showAllRefinements('rb_Location'); return false;" onkeyup="if (event.keyCode == 13) showAllRefinements('rb_Location'); return false;" tabindex="0">
#              more »
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="rbSection rbOpen" id="rb_Company">
#           <div class="rbHeader">
#            <span aria-level="3" class="ws_bold" role="heading">
#             Company
#            </span>
#           </div>
#           <div class="rbsrbo" id="COMPANY_rbo">
#            <ul class="rbList">
#             <li onmousedown="rbptk('rb', 'cmp', '1');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=ADP&amp;jcid=e996c2d6855fe778" rel="nofollow" title="ADP (25)">
#               ADP
#              </a>
#              (25)
#             </li>
#             <li onmousedown="rbptk('rb', 'cmp', '2');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Georgia+Tech+Research+Institute&amp;jcid=d9c58fbcc2c9bece" rel="nofollow" title="Georgia Tech Research Institute (18)">
#               Georgia Tech Research Institute
#              </a>
#              (18)
#             </li>
#             <li onmousedown="rbptk('rb', 'cmp', '3');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Children%27s+Healthcare+of+Atlanta&amp;jcid=5d7180a195e12cf4" rel="nofollow" title="Children's Healthcare of Atlanta (11)">
#               Children's Healthcare of Atlanta
#              </a>
#              (11)
#             </li>
#             <li onmousedown="rbptk('rb', 'cmp', '4');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Oak+Ridge+Associated+Universities&amp;jcid=9bde7059673c2cbc" rel="nofollow" title="Oak Ridge Associated Universities (9)">
#               Oak Ridge Associated Universities
#              </a>
#              (9)
#             </li>
#             <li onmousedown="rbptk('rb', 'cmp', '5');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Centers+for+Disease+Control+and+Prevention&amp;jcid=3e901f592b439cea" rel="nofollow" title="Centers for Disease Control and Prevention (8)">
#               Centers for Disease Control and Prevention
#              </a>
#              (8)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '6');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=KPMG&amp;jcid=2dd390c3a48a7ed0" rel="nofollow" title="KPMG (8)">
#               KPMG
#              </a>
#              (8)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '7');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=GE+Power&amp;jcid=36cd83a149f09757" rel="nofollow" title="GE Power (7)">
#               GE Power
#              </a>
#              (7)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '8');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Honeywell&amp;jcid=50208b5bf45ee3b8" rel="nofollow" title="Honeywell (6)">
#               Honeywell
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '9');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Georgia+Tech&amp;jcid=db25687464a9ecf6" rel="nofollow" title="Georgia Tech (6)">
#               Georgia Tech
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '10');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Emory+University&amp;jcid=efe5e2d22a1d29e5" rel="nofollow" title="Emory University (6)">
#               Emory University
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '11');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Reed+Elsevier&amp;jcid=f7a0f0e88ce3d78e" rel="nofollow" title="Reed Elsevier (6)">
#               Reed Elsevier
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '12');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Equifax&amp;jcid=34c446722f3cf576" rel="nofollow" title="Equifax (6)">
#               Equifax
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '13');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=ICF&amp;jcid=cc35f9c14f8799a9" rel="nofollow" title="ICF (6)">
#               ICF
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '14');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=AT%26T&amp;jcid=25b5166547bbf543" rel="nofollow" title="AT&amp;T (6)">
#               AT&amp;T
#              </a>
#              (6)
#             </li>
#             <li class="moreLi" onmousedown="rbptk('rb', 'cmp', '15');">
#              <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Home+Depot&amp;jcid=16ef23d67d728b35" rel="nofollow" title="Home Depot (6)">
#               Home Depot
#              </a>
#              (6)
#             </li>
#            </ul>
#            <div class="more_link">
#             <span onclick="showAllRefinements('rb_Company'); return false;" onkeyup="if (event.keyCode == 13) showAllRefinements('rb_Company'); return false;" tabindex="0">
#              more »
#             </span>
#            </div>
#           </div>
#          </div>
#          <div class="rbSection rbOpen" id="rb_Experience Level">
#           <div class="rbHeader">
#            <span aria-level="3" class="ws_bold" role="heading">
#             Experience Level
#            </span>
#           </div>
#           <div class="rbsrbo" id="EXP_LVL_rbo">
#            <ul class="rbList">
#             <li onmousedown="rbptk('rb', 'explvl', '1');">
# ...
#               $77,746
#              </span>
#              <span class="univsrch-salary-indicator-max">
#               $167,454
#              </span>
#             </div>
#             <div id="univsrch-salary-indicator-bar">
#              <span class="univsrch-salary-indicator-bar-left">
#              </span>
#              <span class="univsrch-salary-indicator-bar-line">
#              </span>
#              <span class="univsrch-salary-indicator-bar-dot">
#              </span>
#              <span class="univsrch-salary-indicator-bar-right">
#              </span>
#             </div>
#             <div id="univsrch-salary-indicator-labels">
#              <span class="univsrch-salary-indicator-label-common">
#               Common
#              </span>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div id="univsrch-salary-stats">
#           <p id="univsrch-salary-stats-para">
#            Estimated salary from 5 employees and 256 jobs
#            <img id="univsrch-salary-stats-logo" src="/images/univsrch/icon_question_mark_grey.png"/>
#           </p>
#          </div>
#         </div>
#         <script type="text/javascript">
#          usBindSalaryWidgetLogging();
#         </script>
#        </td>
#       </tr>
#      </table>
#      <div class="prime-popover" id="prime-popover-background">
#      </div>
#      <div class="prime-popover" id="prime-popover-div">
#       <div id="prime-popover-x">
#        <button aria-label="close" id="prime-popover-close-button">
#         <span>
#          ×
#         </span>
#        </button>
#       </div>
#       <style type="text/css">
#        #prime_promo_logos {
#         width: 620px;
#         height: 436px;
#     }
#
#     #prime_promo_logos .heading_logo_div {
#         margin: 30px 0 24px 0;
#         text-align: center;
#     }
#
#     #prime_promo_logos .heading_logo_div .heading_logo {
#         max-height: 50px;
#         vertical-align: middle;
#     }
#
#     #prime_promo_logos .heading {
#         font-size: 24px;
#         color: #ff6600;
#         text-align: center;
#         line-height: 26px;
#     }
#
#     #prime_promo_logos .subheading {
#         font-size: 15px;
#         color: #666666;
#         text-align: center;
#         margin-top: 15px;
#         margin-bottom: 25px;
#     }
#
#     #prime_promo_logos .content {
#         background: #F8F8F8;
#     }
#
#     #prime_promo_logos .content .legal {
#         font-size: 11px;
#         color: #666666;
#         padding-top: 15px;
#         padding-bottom: 20px;
#         text-align: center;
#     }
#
#     #prime_promo_logos .apply_div {
#         margin-top: 22px;
#         margin-bottom: 31px;
#     }
#
#     #learnMore {
#         color: #FFFFFF;
#         text-decoration: none !important;
#         font-size: 18px;
#         font-weight: bold;
#     }
#
#     #learnMore:hover,  #learnMore:focus {
#         text-decoration: none !important;
#     }
#
#     #prime_promo_logos .logo_div div {
#         display: inline-block;
#         width: 144px;
#         height: 35px;
#         text-align: center;
#     }
#
#     #prime_promo_logos .logo {
#         padding: 0 22.5px 0 22.5px;
#         max-width: 576px;
#         max-height: 94px;
#     }
#
#     #prime_promo_logos .logo_center_helper {
#         display: inline-block;
#         height: 100%;
#         vertical-align: middle;
#     }
#
#     #learnMore_div {
#         text-align: center;
#     }
#     #hiddenPrimeButton {
#         height: 0;
#         border: 0;
#         width: 0;
#         padding: 0;
#     }
#       </style>
#       <div id="prime_promo_logos">
#        <div class="heading_logo_div">
#         <span class="logo_center_helper">
#         </span>
#         <img alt="Indeed Prime" class="heading_logo" src="/images/prime/indeed_prime_logo.png"/>
#        </div>
#        <div class="heading">
#         <b>
#          3 minutes
#         </b>
#         could get you
#        </div>
#        <div class="heading">
#         <b>
#          10 offers
#         </b>
#         from top tech companies
#        </div>
#        <div class="subheading">
#         Receive a $2,000 Prime bonus if you get hired on Indeed Prime
#        </div>
#        <div class="apply_div" id="learnMore_div">
#         <button autofocus="" id="hiddenPrimeButton" tabindex="-1">
#         </button>
#         <a class="roundedCorner indeedblue" href="/promo/prime" id="learnMore" onclick="this.href = appendParamsOnce( this.href, '?from=primepopover&amp;subfrom=primepopover&amp;trk.origin=jobsearch&amp;trk.variant=primepopover&amp;trk.tk=1b1pgpoksa4cl8m2&amp;vertical=TECH&amp;x_isid=primepopover&amp;x_ikw=Data+Scientist')" role="button">
#          Learn More
#         </a>
#        </div>
#        <div class="content">
#         <div class="logo_div">
#          <div>
#           <span class="logo_center_helper">
#           </span>
#           <img alt="Dropbox, Evernote, Facebook, Redfin, Twilio, Uber, Slack... and more!" class="logo" src="/images/prime/cmp-logos.png"/>
#          </div>
#         </div>
#         <div class="legal">
#          Representative Companies Using Indeed Prime
#         </div>
#        </div>
#       </div>
#      </div>
#      <style type="text/css">
#       #prime-popover-background {
#         z-index: 2;
#         background: #000000;
#         width: 100%;
#         height: 100%;
#         opacity: .30;
#         filter: alpha(opacity=30);
#         top: 0;
#     }
#     #prime-popover-x {
#         float: right;
#         margin: 1px 1px 0 0;
#         cursor: pointer;
#         font-weight: bold;
#         font-size: 18px;
#         color: #666;
#     }
#     #prime-popover-close-button {
#         background:none;
#         border:none;
#         font-weight: bold;
#         font-size: 18px;
#         color: #666;
#     }
#     #prime-popover-close-button:hover {
#         cursor: pointer;
#     }
#     .prime-popover {
#         position: fixed;
#         display: none;
#     }
#     #prime-popover-div {
#         z-index: 3;
#         height: auto;
#         width: auto;
#         background: #ffffff;
#         display: none; /*hide before the cookie check*/
#         max-width: 620px;
#     }
#
#     #prime_promo {
#         background:#ffffff
#     }
#      </style>
#      <script type="text/javascript">
#       window['primePopoverShown'] = 'popover';
#      </script>
#      <script>
#       var focusHandlers = [];
# var linkHighlighter = new LinkHighlighter();
# focusHandlers.push(googBind(linkHighlighter.fadeToOriginalColor, linkHighlighter));
# var lostFocusHandlers = [];
# lostFocusHandlers.push(googBind(linkHighlighter.clickedAway, linkHighlighter, "#551a8b"));
#
#
# var didYouApplyPrompt = new DidYouApplyPrompt('1b1pgpoona4clbpa',
# 60, 'serp', false);
# focusHandlers.push(googBind(didYouApplyPrompt.returnedToPage, didYouApplyPrompt));
# lostFocusHandlers.push(googBind(didYouApplyPrompt.leftPage, didYouApplyPrompt));
# didYouApplyPrompt.dyaChangeFromCookie();
#
# var clickTime = new ClickTime(window.tk, 'serp', 'jobtitle', focusHandlers, lostFocusHandlers);
#      </script>
#      <script>
#       enableAdometry();
#      </script>
#      <script>
#       usBindRightRailLogging();
#      </script>
#      <style type="text/css">
#       #secondary_nav a,#secondary_nav a:link,#secondary_nav a:visited{color:#77c;text-decoration:none}#secondary_nav a:hover{text-decoration:underline}
#      </style>
#      <!-- jobs -->
#      <div id="footerWrapper" role="contentinfo" style="text-align:center;">
#       <div id="footer" style="text-align:left;">
#        <div class="separator_bottom">
#        </div>
#        <div id="secondary_nav">
#         <div style="margin: 1em;">
#          <span class="gaj_heading">
#           Indeed helps people get jobs:
#          </span>
#          <a class="sl" href="/promo/gotajob" onmousedown="this.href = appendParamsOnce( this.href, '?trk.origin=jobsearch&amp;trk.tk=1b1pgpoona4clbpa')">
#           Over 2.8 million stories shared
#          </a>
#         </div>
#         <a href="/" id="jobs_product_link" title="Jobs">
#          Jobs
#         </a>
#         -
#         <a href="/Best-Places-to-Work" id="companies_product_link" title="Browse Companies">
#          Browse Companies
#         </a>
#         -
#         <a href="/salary" id="salaries_product_link" title="Salary Search">
#          Salaries
#         </a>
#         -
#         <a href="/jobtrends" id="trends_product_link" title="Career Trends">
#          Trends
#         </a>
#         -
#         <a href="/forum" id="forums_product_link" title="Employment Forums">
#          Forums
#         </a>
#         -
#         <script type="text/javascript">
#          var jobsProductLink = document.getElementById('jobs_product_link');
# document.getElementById('salaries_product_link').onclick = function() { if ( !document.js ) { return; } var q = document.js.q.value; var l = document.js.l.value; if ( q || l ) { window.location = '/salary?q1=' + urlencode( q ) + '&l1=' + urlencode( l ); return false; } };document.getElementById('trends_product_link').onclick = function() { if ( !document.js ) { return; } var q = document.js.q.value; if ( q ) { window.location = '/jobtrends?q=' + urlencode( q ) + '&l=' + urlencode( document.js.l.value ); return false; } };document.getElementById('forums_product_link').onclick = function() { if ( !document.js ) { return; } var q = document.js.q.value; if ( q ) { window.location = '/forum/?q=' + urlencode( q ) + '&l=' + urlencode( document.js.l.value ); return false; } };document.getElementById('companies_product_link').onclick = function() { window.location = '/Best-Places-to-Work?campaignid=jobs'; return false;};
#         </script>
#         <a href="/find-jobs.jsp">
#          Browse Jobs
#         </a>
#         -
#         <a href="/tools/jobseeker/">
#          Tools
#         </a>
#         -
#         <a href="http://www.indeed.jobs">
#          Work at Indeed
#         </a>
#         -
#         <a href="/publisher">
#          API
#         </a>
#         -
#         <a href="/intl/en/about.html">
#          <nobr>
#           About
#          </nobr>
#         </a>
#         -
#         <a href="https://indeed.zendesk.com/hc/en-us">
#          Help Center
#         </a>
#         <style type="text/css">
#          #footer-legal {
# margin-top: 10px;
# font-size: 9pt;
# }
#         </style>
#         <div id="footer-legal">
#          <div class="legal-footer">
#           ©2016 Indeed -
#           <a href="/legal">
#            Cookies, Privacy and Terms
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </td>
#    </tr>
#   </table>
#   <script type="text/javascript">
#    function sm_cv_tag(activityId) {
#             var ebRand = Math.random()+'';
#             ebRand = ebRand * 1000000;
#
#             var tagContainer = document.body.appendChild(document.createElement("div"));
#             tagContainer.style.position="absolute";
#             tagContainer.style.top="0";
#             tagContainer.style.left="0";
#             tagContainer.style.width="1px";
#             tagContainer.style.height="1px";
#             tagContainer.style.display="none";
#
#             var jsTag = document.createElement('script');
#             jsTag.src = '//bs.serving-sys.com/Serving/ActivityServer.bs?cn=as&ActivityID=' + activityId + '&rnd=' + ebRand;
#             jsTag.setAttribute('crossorigin', 'anonymous');
#             jsTag.style.width="1px";
#             jsTag.style.height="1px";
#             jsTag.style.border="0";
#
#             var noScript = document.createElement("noscript");
#             var noScriptText = '<img width="1" height="1" style="border:0" src="//bs.serving-sys.com/Serving/ActivityServer.bs?cn=as&ActivityID=' + activityId + '&ns=1"/>';
#
#             // IE less than 9 and RCs do not support innerHTML on some DOM elements, but supports .text for it
#             if (((typeof noScript.canHaveHTML) === "boolean") && (noScript.canHaveHTML === false)) { // canHaveHTML only exists for IE
#                 noScript.text = noScriptText;
#             } else {
#                 noScript.innerHTML = noScriptText;
#             }
#
#             tagContainer.appendChild(jsTag);
#             tagContainer.appendChild(noScript);
#         }
#   </script>
#   <script type="text/javascript">
#    <!--
# (function ( tk ) { if ( tk && document.images ) { var s="/", q="?", a="&", e="="; rpc(s+"rpc"+s+"log"+q+"a"+e+"jsv"+a+"tk"+e+tk); } })('1b1pgpoona4clbpa');
# function jsall_loaded() {
#
#
# initProcessLeftoverDwellEntries();
#
# attachSjBlock('');
# attachJaBlock('');
# }
# if (window['closureReady'] === true) {
# jsall_loaded();
# }
# //-->
#   </script>
#   <script type="text/javascript">
#    PENDING_ANALYTICS_VARS = window.PENDING_ANALYTICS_VARS || [];
# PENDING_ANALYTICS_VARS[PENDING_ANALYTICS_VARS.length] = ['_setCustomVar', 5, 'loggedIn', 'false', 3];
#   </script>
#   <script type="text/javascript">
#    var ga_domains = [];
#         ga_domains.push('indeed.co.in');ga_domains.push('indeed.lu');ga_domains.push('indeed.fr');ga_domains.push('indeed.de');ga_domains.push('indeed.com.br');ga_domains.push('indeed.co.uk');ga_domains.push('indeed.hk');ga_domains.push('indeed.fi');ga_domains.push('indeed.pt');ga_domains.push('indeed.jp');ga_domains.push('indeed.com');ga_domains.push('indeed.com.sg');ga_domains.push('indeed.nl');ga_domains.push('indeed.com.pk');ga_domains.push('indeed.cl');ga_domains.push('indeed.es');ga_domains.push('indeed.co.ve');ga_domains.push('indeed.ae');ga_domains.push('indeed.com.mx');ga_domains.push('indeed.com.my');ga_domains.push('indeed.ch');ga_domains.push('indeed.com.co');ga_domains.push('indeed.com.ph');ga_domains.push('indeed.co.za');ga_domains.push('indeed.ie');ga_domains.push('indeed.com.au');ga_domains.push('indeed.ca');ga_domains.push('indeed.com.pe');
#
#         (function (i, s, o, g, r, a, m) {
#             i['GoogleAnalyticsObject'] = r;
#             i[r] = i[r] || function () {
#                 (i[r].q = i[r].q || []).push(arguments)
#             }, i[r].l = 1 * new Date();
#             a = s.createElement(o),
#                     m = s.getElementsByTagName(o)[0];
#             a.async = 1;
#             a.src = g;
#             m.parentNode.insertBefore(a, m)
#         })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#         var ga = ga || [];
#         ga('create', 'UA-90780-1', 'auto', {
#             'allowLinker': true
#         });
#         ga('require', 'linkid');
#         ga('require', 'linker');
#         ga('linker:autoLink', ga_domains, false, true);
#         ga('require', 'displayfeatures');
#         ga('send', 'pageview');
#
#
#         (function () {
#             if (window.PENDING_ANALYTICS_VARS && window.PENDING_ANALYTICS_VARS.length > 0) {
#                 for (var i in PENDING_ANALYTICS_VARS) {
#                     ga('set', PENDING_ANALYTICS_VARS[i][2], PENDING_ANALYTICS_VARS[i][3]);
#                 }
#             }
#         })();
#   </script>
#   <!-- Facebook Pixel Code -->
#   <script>
#    !function(f,b,e,v,n,t,s){if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#             n.callMethod.apply(n,arguments):n.queue.push(arguments)};if(!f._fbq)f._fbq=n;
#         n.push=n;n.loaded=!0;n.version='2.0';n.queue=[];t=b.createElement(e);t.async=!0;
#         t.src=v;s=b.getElementsByTagName(e)[0];s.parentNode.insertBefore(t,s)}(window,
#             document,'script','https://connect.facebook.net/en_US/fbevents.js');
#
#     fbq('init', '579216298929618');
#     fbq('track', "PageView");
#   </script>
#   <noscript>
#    <img height="1" src="https://www.facebook.com/tr?id=579216298929618&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Facebook Pixel Code -->
#   <script>
#    var _comscore = _comscore || [];
# _comscore.push({ c1: "2", c2: "6486505", c4:"www.indeed.com/q-Data-Scientist-l-Atlanta,-GA-jobs.html", c15:"1b1pgpoksa4cl8m2"});
# (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#   </script>
#   <noscript>
#    <img alt="" height="0" src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6486505&amp;c4=www.indeed.com%2Fq-Data-Scientist-l-Atlanta%2C-GA-jobs.html&amp;c15=1b1pgpoksa4cl8m2&amp;cv=2.0&amp;cj=1" style="display:none" width="0"/>
#   </noscript>
#   <img height="0" src="//log.dmtry.com/redir/1/0/4102/1011464/0/1/189/0/1017/1.ver?at=v&amp;d=PxConv" width="0"/>
#  </body>
# </html>

# %%
soup.find_all('a')
# Out:
# [<a class="accessibilityMenu" href="#jobPostingsAnchor" id="skipToJobs">Job Postings</a>,
#  <a class="accessibilityMenu" href="#what" id="skipToSearch">Search</a>,
#  <a id="accessibilityClose">Close</a>,
#  <a class="selected" href="/" id="jobsLink" title="Jobs">Find Jobs</a>,
#  <a href="/resumes?isid=find-resumes&amp;ikw=SERPtop&amp;co=US&amp;hl=en" id="rezLink">Find Resumes</a>,
#  <a href="/hire?hl=en&amp;cc=US" id="empLink" onclick="if ( this.href.match('&amp;isid=employerlink-US-control&amp;ikw=SERPtop') == null ) { this.href += '&amp;isid=employerlink-US-control&amp;ikw=SERPtop' };">Employers / Post Job</a>,
#  <a href="/promo/resume" onclick="window.location=this.href + '?from=nav&amp;subfrom=rezprmstd&amp;trk.origin=jobsearch&amp;trk.variant=rezprmstd&amp;trk.tk=1b1pgpoona4clbpa'; return false;">Upload your resume</a>,
#  <a href="http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3DData%2BScientist%26l%3DAtlanta%2C%2BGA" id="userOptionsLabel" rel="nofollow">Sign in</a>,
#  <a href="/" id="branding" onmousedown="ptk('logo');"><img alt="one search. all jobs. Indeed" class="indeedLogo" src="..." style="margin-bottom:6px;display:block;" title="one search. all jobs. Indeed"/></a>,
#  <a class="sl" href="/advanced_search?q=Data+Scientist&amp;l=Atlanta%2C+GA">Advanced Job Search</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;sort=date" rel="nofollow">date</a>,
#  <a href="/q-Data-Scientist-$55,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$55,000+ (298)">$55,000+</a>,
#  <a href="/q-Data-Scientist-$70,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$70,000+ (252)">$70,000+</a>,
#  <a href="/q-Data-Scientist-$85,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$85,000+ (191)">$85,000+</a>,
#  <a href="/q-Data-Scientist-$100,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$100,000+ (125)">$100,000+</a>,
#  <a href="/q-Data-Scientist-$115,000-l-Atlanta,-GA-jobs.html" rel="nofollow" title="$115,000+ (65)">$115,000+</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=fulltime" rel="nofollow" title="Full-time (317)">Full-time</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=contract" rel="nofollow" title="Contract (23)">Contract</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=internship" rel="nofollow" title="Internship (10)">Internship</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=parttime" rel="nofollow" title="Part-time (8)">Part-time</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=commission" rel="nofollow" title="Commission (2)">Commission</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;jt=temporary" rel="nofollow" title="Temporary (2)">Temporary</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Atlanta,+GA&amp;jlid=966e6327a98f7e81" rel="nofollow" title="Atlanta, GA (255)">Atlanta, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Alpharetta,+GA&amp;jlid=136fb7555504878c" rel="nofollow" title="Alpharetta, GA (65)">Alpharetta, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Duluth,+GA&amp;jlid=ed96b91845c744fe" rel="nofollow" title="Duluth, GA (10)">Duluth, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Marietta,+GA&amp;jlid=528fb8dbaacbeb3b" rel="nofollow" title="Marietta, GA (6)">Marietta, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Norcross,+GA&amp;jlid=61b742028b096345" rel="nofollow" title="Norcross, GA (4)">Norcross, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Berkeley+Lake,+GA&amp;jlid=1b2f56c7228d460f" rel="nofollow" title="Berkeley Lake, GA (3)">Berkeley Lake, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Johns+Creek,+GA&amp;jlid=b258b190889f0f22" rel="nofollow" title="Johns Creek, GA (3)">Johns Creek, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Decatur,+GA&amp;jlid=f9ba64383bdcdb29" rel="nofollow" title="Decatur, GA (2)">Decatur, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Smyrna,+GA&amp;jlid=254cfc0ab0df7665" rel="nofollow" title="Smyrna, GA (2)">Smyrna, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Stone+Mountain,+GA&amp;jlid=24923703f25e1c15" rel="nofollow" title="Stone Mountain, GA (2)">Stone Mountain, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Roswell,+GA&amp;jlid=abf990a05b719190" rel="nofollow" title="Roswell, GA (2)">Roswell, GA</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbl=Kennesaw,+GA&amp;jlid=382ecefe55e0ce93" rel="nofollow" title="Kennesaw, GA (2)">Kennesaw, GA</a>,
#  <a href="/q-Data-Scientist-jobs.html">Data Scientist jobs</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=ADP&amp;jcid=e996c2d6855fe778" rel="nofollow" title="ADP (25)">ADP</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Georgia+Tech+Research+Institute&amp;jcid=d9c58fbcc2c9bece" rel="nofollow" title="Georgia Tech Research Institute (18)">Georgia Tech Research Institute</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Children%27s+Healthcare+of+Atlanta&amp;jcid=5d7180a195e12cf4" rel="nofollow" title="Children's Healthcare of Atlanta (11)">Children's Healthcare of Atlanta</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Oak+Ridge+Associated+Universities&amp;jcid=9bde7059673c2cbc" rel="nofollow" title="Oak Ridge Associated Universities (9)">Oak Ridge Associated Universities</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Centers+for+Disease+Control+and+Prevention&amp;jcid=3e901f592b439cea" rel="nofollow" title="Centers for Disease Control and Prevention (8)">Centers for Disease Control and Prevention</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=KPMG&amp;jcid=2dd390c3a48a7ed0" rel="nofollow" title="KPMG (8)">KPMG</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=GE+Power&amp;jcid=36cd83a149f09757" rel="nofollow" title="GE Power (7)">GE Power</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Honeywell&amp;jcid=50208b5bf45ee3b8" rel="nofollow" title="Honeywell (6)">Honeywell</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Georgia+Tech&amp;jcid=db25687464a9ecf6" rel="nofollow" title="Georgia Tech (6)">Georgia Tech</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Emory+University&amp;jcid=efe5e2d22a1d29e5" rel="nofollow" title="Emory University (6)">Emory University</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Reed+Elsevier&amp;jcid=f7a0f0e88ce3d78e" rel="nofollow" title="Reed Elsevier (6)">Reed Elsevier</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Equifax&amp;jcid=34c446722f3cf576" rel="nofollow" title="Equifax (6)">Equifax</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=ICF&amp;jcid=cc35f9c14f8799a9" rel="nofollow" title="ICF (6)">ICF</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=AT%26T&amp;jcid=25b5166547bbf543" rel="nofollow" title="AT&amp;T (6)">AT&amp;T</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;rbc=Home+Depot&amp;jcid=16ef23d67d728b35" rel="nofollow" title="Home Depot (6)">Home Depot</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;explvl=mid_level" rel="nofollow" title="Mid Level (126)">Mid Level</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;explvl=entry_level" rel="nofollow" title="Entry Level (108)">Entry Level</a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta,+GA&amp;explvl=senior_level" rel="nofollow" title="Senior Level (65)">Senior Level</a>,
#  <a href="/promo/prime" onclick="this.href = appendParamsOnce( this.href, '?from=serptop&amp;subfrom=primeprmtop&amp;trk.origin=jobsearch&amp;trk.variant=primeprmtop&amp;trk.tk=1b1pgpoona4clbpa&amp;vertical=TECH&amp;x_isid=serptop&amp;x_ikw=Data+Scientist')">Join Indeed Prime</a>,
#  <a id="jobPostingsAnchor" tabindex="-1"></a>,
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0AbexXlh6WlNaC12RNLKcRQH8fywLm61v9KQllly0vTVrm9U0Iy0AOsYwOq9YOpDX03iprvWHw_SY6xCXG90mwLvOd8fb5BdJ-fu_-2tfp_KoWry1hPm7FaVRyBGPoeYEaNltu7W5i0j7KlWZFPmjLgIWx7L0bFO3kcNnufTddaPcPcV082PCVLmtiO_gyjP5gFnbtJj9GkA18deOm7BUQ0am2kTh-5rnprLl8sW589sA1w53JEauGHLmIfOZq04N98GivGmhlR-hxB6lwRkUZWzZOmHIdil7qIRSWrkC_monBcQ2wvbCJ8XUUr5FCwLNts-NXWaBzHtzhCoa6fFkV1G76AnCf3hxVnt5eLPzzGrTCZ3kNaEM49ZYMRwYjX8HUOsjrJpTE5TDrYJg7qf4vU_H8hGi-AF6URkOUThbwJwruOBLhsdB_IA0dnK4JHNENFtMqis9ylt63uSuhgN0Mw&amp;p=1&amp;sk=&amp;fvj=0" id="sja1" onclick="setRefineByCookie([]); sjoc('sja1',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja1'); clk('sja1');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Cotiviti" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=28c4f77bbe45925e&amp;jcid=c3f06afea9b49370')" target="_blank">\n        Cotiviti</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Cotiviti/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=28c4f77bbe45925e&amp;jcid=c3f06afea9b49370');" target="_blank" title="Cotiviti reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.2px;"><!-- --></span></span><span class="slNoUnderline">30 reviews</span></a>,
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0ADQeWqYYwuRDGK7FTA-YzU7Qag1HzehP-FB7aWzkBO6FRyVCTNkBclA9FrQyCAXLjn4u9IP3mepDeJnt-BtuBzfosurWUx8dMI4PS2dnzCGDjcb1rqHXIXHxiVvQw9rfF11WZQLdcQkIzgltmPYW2VvburimlHlkyDe_B_oHUYECMKEjBspsWtp3Q3HXZX2ldmjzaf3Pl0W1SUQWeOTehXzioQffBFoy_bLgTc4p96VXojEChOjrJ7bnRWuW76C17FN_y1xORn9gxfh72Cea0uuJpSTvDAOaFzFr-jBhg2lYfT-IowonC3j0c09SkgDXIDJlgD9mnxFplaPnEm9XZCozK6CEk23fzdVCZNcY2UD62tRTmScY8VaNVgMfabc6u4-xrNvjchT8zzXQVOsqR_2mJzF6ZV2Y8KKdnWstkepYM2TYTmB8ESfc7JyCaitJdsGHK5qe1GMQ==&amp;p=2&amp;sk=&amp;fvj=1" id="sja2" onclick="setRefineByCookie([]); sjoc('sja2',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja2'); clk('sja2');" rel="nofollow" target="_blank" title="Data Scientist With Predictive Modeling"><b>Data</b> <b>Scientist</b> With Predictive Modeling</a>,
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0Bcgobz-t7weSGYTjoRWMIqcV9t0akB45B3k8NFJVZb5kkFpxn8bhfjltbVDjvx0bn0noTLqpSBW77839Ubfh4eL2ZvByfFlPegJkfgxbap4qbKzQXknClXAKQmaD18uRE6WyuXyxO_e8fzaqQSa7ZpxGZdW1QTr8PcL2Bkb24IpMS8LEQEQJPDWDX6LECH9ECkPSzAuxndU83nIA26ZgbZgH86G_X92KoN901nIKR14nUpH9Aln800WvE6PbZ8uQkL379Ds8upAIGVFRFz3AOC7Y4vkDoYXejADzEb41HfvTuFicGrbQBCEZsfw_Xchn7097dG8B6URhozWGeiuegsxwZUa4ga8_LJiiwo8NH8nVTxr3a4IbkEbx0h6bQ8iU4lOrYll-65kJiYkVuJTg77VK-OO5DunG0=&amp;p=3&amp;sk=&amp;fvj=0" id="sja3" onclick="setRefineByCookie([]); sjoc('sja3',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja3'); clk('sja3');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/company/Vision3-Solutions,-Inc/jobs/Data-Scientist-1a8c086f5f6f1294?r=1&amp;fccid=37d33d67f3fba52b" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[0],true,1);" onmousedown="return rclk(this,jobmap[0],1);" rel="nofollow" target="_blank" title="Data Scientist- Big Data"><b>Data</b> <b>Scientist</b>- Big <b>Data</b></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_1a8c086f5f6f1294" onclick="changeJobState('1a8c086f5f6f1294', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_0" onclick="toggleMoreLinks('1a8c086f5f6f1294'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('1a8c086f5f6f1294'); return false;" title="Close"></a>,
#  <a href="/jobs?q=Vision3+Solutions,+Inc&amp;l=Atlanta,+GA&amp;nc=jasx" rel="nofollow">Vision3 Solutions, Inc jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in Atlanta, GA</a>,
#  <a href="/cmp/Vision3-Solutions,-Inc" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=1a8c086f5f6f1294&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=e54b646b0aef4211');">Vision3 Solutions, Inc</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Vision3-Solutions%2C-Inc.html">Vision3 Solutions, Inc</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/company/FraudScope/jobs/Data-Scientist-d72c337465398caf?r=1&amp;fccid=e87f46501099545c" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[1],true,0);" onmousedown="return rclk(this,jobmap[1],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_d72c337465398caf" onclick="changeJobState('d72c337465398caf', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_1" onclick="toggleMoreLinks('d72c337465398caf'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('d72c337465398caf'); return false;" title="Close"></a>,
#  <a href="/q-Fraudscope-l-Atlanta,-GA-jobs.html" rel="nofollow">FraudScope jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in Atlanta, GA</a>,
#  <a href="/cmp/Fraudscope-1" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=d72c337465398caf&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=69e48b1f7c3ce51e');">Fraudscope</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Fraudscope-1.html">FraudScope</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=d21cbd39fb6dd414&amp;fccid=25b5166547bbf543" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[2],true,0);" onmousedown="return rclk(this,jobmap[2],0);" rel="nofollow" target="_blank" title="AT&amp;T Professional Data Scientist Alpharetta GA">AT&amp;T Professional <b>Data</b> <b>Scientist</b> Alpharetta GA</a>,
#  <a href="/cmp/AT&amp;T" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=d21cbd39fb6dd414&amp;jcid=25b5166547bbf543')" target="_blank">\n        AT&amp;T</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/AT&amp;T/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=AT%26T+Professional+Data+Scientist+Alpharetta+GA&amp;fromjk=d21cbd39fb6dd414&amp;jcid=25b5166547bbf543');" target="_blank" title="AT&amp;T reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 44.4px;"><!-- --></span></span><span class="slNoUnderline">14,560 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_d21cbd39fb6dd414" onclick="changeJobState('d21cbd39fb6dd414', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_2" onclick="toggleMoreLinks('d21cbd39fb6dd414'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('d21cbd39fb6dd414'); return false;" title="Close"></a>,
#  <a href="/q-AT&amp;T-l-Alpharetta,-GA-jobs.html" rel="nofollow">AT&amp;T jobs in Alpharetta, GA</a>,
#  <a href="/l-Alpharetta,-GA-jobs.html">Alpharetta jobs</a>,
#  <a href="/salary?q1=AT%26T+Professional+Data+Scientist&amp;l1=Alpharetta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">AT&amp;T Professional Data Scientist salaries in Alpharetta, GA</a>,
#  <a href="/cmp/AT&amp;T" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=d21cbd39fb6dd414&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=25b5166547bbf543');">AT&amp;T</a>,
#  <a href="/forum/loc/Alpharetta-Georgia.html">Alpharetta, Georgia</a>,
#  <a href="/forum/cmp/AT%26T.html">AT&amp;T</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=4a4948fe135cb354&amp;fccid=cc35f9c14f8799a9" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[3],true,0);" onmousedown="return rclk(this,jobmap[3],0);" rel="nofollow" target="_blank" title="Scientific Data Analyst">Scientific <b>Data</b> Analyst</a>,
#  <a href="/cmp/Icf" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4a4948fe135cb354&amp;jcid=cc35f9c14f8799a9')" target="_blank">\n        ICF</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Icf/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Scientific+Data+Analyst&amp;fromjk=4a4948fe135cb354&amp;jcid=cc35f9c14f8799a9');" target="_blank" title="Icf reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 41.4px;"><!-- --></span></span><span class="slNoUnderline">235 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_4a4948fe135cb354" onclick="changeJobState('4a4948fe135cb354', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_3" onclick="toggleMoreLinks('4a4948fe135cb354'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('4a4948fe135cb354'); return false;" title="Close"></a>,
#  <a href="/q-Icf-l-Atlanta,-GA-jobs.html" rel="nofollow">ICF jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Scientific+Data+Analyst&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Scientific Data Analyst salaries in Atlanta, GA</a>,
#  <a href="/cmp/Icf" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=4a4948fe135cb354&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=cc35f9c14f8799a9');">Icf</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Icf.html">ICF</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=a959ea9503eb0043&amp;fccid=11619ce0d3c2c733" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[4],true,0);" onmousedown="return rclk(this,jobmap[4],0);" rel="nofollow" target="_blank" title="Scientific Data Analyst">Scientific <b>Data</b> Analyst</a>,
#  <a href="/cmp/Northrop-Grumman" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=a959ea9503eb0043&amp;jcid=11619ce0d3c2c733')" target="_blank">\n        Northrop Grumman</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Northrop-Grumman/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Scientific+Data+Analyst&amp;fromjk=a959ea9503eb0043&amp;jcid=11619ce0d3c2c733');" target="_blank" title="Northrop Grumman reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 51.0px;"><!-- --></span></span><span class="slNoUnderline">2,159 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_a959ea9503eb0043" onclick="changeJobState('a959ea9503eb0043', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_4" onclick="toggleMoreLinks('a959ea9503eb0043'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('a959ea9503eb0043'); return false;" title="Close"></a>,
#  <a href="/q-Northrop-Grumman-l-Atlanta,-GA-jobs.html" rel="nofollow">Northrop Grumman jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Scientific+Data+Analyst&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Scientific Data Analyst salaries in Atlanta, GA</a>,
#  <a href="/cmp/Northrop-Grumman" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=a959ea9503eb0043&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=11619ce0d3c2c733');">Northrop Grumman</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Northrop-Grumman.html">Northrop Grumman</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=cf742a5180d45499&amp;fccid=ddf188c30da34688" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[5],true,0);" onmousedown="return rclk(this,jobmap[5],0);" rel="nofollow" target="_blank" title="Sr. Data Scientist">Sr. <b>Data</b> <b>Scientist</b></a>,
#  <a href="/cmp/Infor" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=cf742a5180d45499&amp;jcid=ddf188c30da34688')" target="_blank">\n        Infor</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Infor/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Sr.+Data+Scientist&amp;fromjk=cf742a5180d45499&amp;jcid=ddf188c30da34688');" target="_blank" title="Infor reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 42.6px;"><!-- --></span></span><span class="slNoUnderline">62 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_cf742a5180d45499" onclick="changeJobState('cf742a5180d45499', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_5" onclick="toggleMoreLinks('cf742a5180d45499'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('cf742a5180d45499'); return false;" title="Close"></a>,
#  <a href="/q-Infor-l-Atlanta,-GA-jobs.html" rel="nofollow">Infor jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Senior+Data+Scientist&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Senior Data Scientist salaries in Atlanta, GA</a>,
#  <a href="/cmp/Infor" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=cf742a5180d45499&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=ddf188c30da34688');">Infor</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Infor.html">Infor</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=ece5708bd668a5e5&amp;fccid=bd2e17bd9d57178b" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[6],true,0);" onmousedown="return rclk(this,jobmap[6],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a href="/cmp/Ignitionone" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=ece5708bd668a5e5&amp;jcid=bd2e17bd9d57178b')" target="_blank">\n        IgnitionOne</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Ignitionone/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=ece5708bd668a5e5&amp;jcid=bd2e17bd9d57178b');" target="_blank" title="Ignitionone reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 42.0px;"><!-- --></span></span><span class="slNoUnderline">8 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_ece5708bd668a5e5" onclick="changeJobState('ece5708bd668a5e5', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_6" onclick="toggleMoreLinks('ece5708bd668a5e5'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('ece5708bd668a5e5'); return false;" title="Close"></a>,
#  <a href="/q-Ignitionone-l-Atlanta,-GA-jobs.html" rel="nofollow">IgnitionOne jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in Atlanta, GA</a>,
#  <a href="/cmp/Ignitionone" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=ece5708bd668a5e5&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=bd2e17bd9d57178b');">Ignitionone</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Ignitionone.html">IgnitionOne</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/company/Ashton212/jobs/Quantitative-Analyst-01ad090d112dbb83?r=1&amp;fccid=f0461620810fcde2" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[7],true,0);" onmousedown="return rclk(this,jobmap[7],0);" rel="nofollow" target="_blank" title="Quantitative Analyst | #769">Quantitative Analyst | #769</a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_01ad090d112dbb83" onclick="changeJobState('01ad090d112dbb83', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_7" onclick="toggleMoreLinks('01ad090d112dbb83'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('01ad090d112dbb83'); return false;" title="Close"></a>,
#  <a href="/q-Ashton212-l-Atlanta,-GA-jobs.html" rel="nofollow">Ashton212 jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Quantitative+Analyst&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Quantitative Analyst salaries in Atlanta, GA</a>,
#  <a href="/cmp/Ashton212" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=01ad090d112dbb83&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=657572328deb01c1');">Ashton212</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Ashton212.html">Ashton212</a>,
#  <a href="/forum/job/Quantitative-Analyst.html">Quantitative Analyst</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=8b1060b171ddf805&amp;fccid=6df24d87c9f05a07" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[8],true,0);" onmousedown="return rclk(this,jobmap[8],0);" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a href="/cmp/Macy's" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=8b1060b171ddf805&amp;jcid=6df24d87c9f05a07')" target="_blank">\n        Macy's</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Macy's/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=8b1060b171ddf805&amp;jcid=6df24d87c9f05a07');" target="_blank" title="Macy's reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.2px;"><!-- --></span></span><span class="slNoUnderline">14,441 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_8b1060b171ddf805" onclick="changeJobState('8b1060b171ddf805', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_8" onclick="toggleMoreLinks('8b1060b171ddf805'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('8b1060b171ddf805'); return false;" title="Close"></a>,
#  <a href="/jobs?q=Macy%27s&amp;l=Atlanta,+GA" rel="nofollow">Macy's jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Data+Scientist&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Data Scientist salaries in Atlanta, GA</a>,
#  <a href="/cmp/Macy's" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=8b1060b171ddf805&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=6df24d87c9f05a07');">Macy's</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Macy%27s.html">Macy's</a>,
#  <a class="turnstileLink" data-tn-element="jobTitle" href="/rc/clk?jk=1ae9fbf052162ca0&amp;fccid=3e901f592b439cea" itemprop="title" onclick="setRefineByCookie([]); return rclk(this,jobmap[9],true,1);" onmousedown="return rclk(this,jobmap[9],1);" rel="nofollow" target="_blank" title="Statistician (Health)">Statistician (Health)</a>,
#  <a href="/cmp/Centers-For-Disease-Control-and-Prevention" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=1ae9fbf052162ca0&amp;jcid=3e901f592b439cea')" target="_blank">\n        Centers for Disease Control and Prevention</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Centers-For-Disease-Control-and-Prevention/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Statistician+%28Health%29&amp;fromjk=1ae9fbf052162ca0&amp;jcid=3e901f592b439cea');" target="_blank">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 54.0px;"><!-- --></span></span><span class="slNoUnderline">66 reviews</span></a>,
#  <a class="sl resultLink save-job-link" href="#" id="sj_1ae9fbf052162ca0" onclick="changeJobState('1ae9fbf052162ca0', 'save', 'linkbar', false);return false;" title="Save this job to my.indeed">save job</a>,
#  <a class="sl resultLink more-link " href="#" id="tog_9" onclick="toggleMoreLinks('1ae9fbf052162ca0'); return false;">more...</a>,
#  <a class="close-link closeLink" href="#" onclick="toggleMoreLinks('1ae9fbf052162ca0'); return false;" title="Close"></a>,
#  <a href="/q-Centers-For-Disease-Control-Prevention-l-Atlanta,-GA-jobs.html" rel="nofollow">Centers for Disease Control and Prevention jobs in Atlanta, GA</a>,
#  <a href="/l-Atlanta,-GA-jobs.html">Atlanta jobs</a>,
#  <a href="/salary?q1=Statistician&amp;l1=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '');">Statistician salaries in Atlanta, GA</a>,
#  <a href="/cmp/Centers-For-Disease-Control-and-Prevention" onmousedown="this.href = appendParamsOnce(this.href, '?fromjk=1ae9fbf052162ca0&amp;from=serp-more&amp;campaignid=serp-more&amp;jcid=3e901f592b439cea');">Centers For Disease Control and Prevention</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html">Atlanta, Georgia</a>,
#  <a href="/forum/cmp/Centers-For-Disease-Control-and-Prevention.html">Centers for Disease Control and Prevention</a>,
#  <a href="/forum/job/Statistician.html">Statistician</a>,
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0BOtxtSuljPipcOqTsdGhy_ryU9_Bpcutm1h1zAeyLmGnpluTyzXEqsxsrMKBlkufFESLwSdxJSAONzh1zkMDi4o-Ahekc18NAvrbyd8GeyF0DRrENb1LzCRVsYrK8Sg_PhO3N5J8mMNMCHG7w2soKtDolHAWh8bQLx4kgUx-edDWDbopKNxeouEV7g13l_uJJCj_WEQDH0ch1-XGO38Mv0osPvhW-UtWERAcFeRlYk4Iu1K_CXhk8QhINCqcWRGslagQ_CWyuz7tj2JQ02XrJQEEsF8P9VpQIYZo5GA_InsjLiwn3Rw2rSFwB-f9UvPji57Z6km78QBkeiXZJk0UumBK7RZsEteEnFRleBcnOKlM0TbhebkriFTWlaArxd9tkbZnr1xU2nMVXHhLhzS3MOIz7PAtQLv2WKiSJil9ot6S9jqvQ_QBFzznHSseOBPnPdV_zwR01qpRxeBwcKXi4X5ck2V-10RHWAqDPJWtwHr_dvWAqpNSARbS7oQwJEmg9vM_g_z2lk6vZqhnhRa7x74iv-mIDeBXV2H_hpXR2BOZROMCao81gVb_PWx5XFe-kiJPwC_NBTE4kjrmOHdDAXd1WW1E3AmnA5yUOC775bpqrG6M-xOjCS3LAi23FLikdyeRx9u3SM2MzlctJUOslzZlT-uMg_oA-BawRylH5DS-IsCsqBJ1E2EOwCrIRqSD90eMDrt--HjsdhbeOL7qw2MfMJ-W28iHZBsI25hooPF4W5CdOV3cqTXwCqledtYFD762mbFaNQIqGpbjlMlJGUoQ-6462ihKI=&amp;p=4&amp;sk=&amp;fvj=0" id="sja4" onclick="setRefineByCookie([]); sjoc('sja4',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja4'); clk('sja4');" rel="nofollow" target="_blank" title="DATA SCIENTIST"><b>DATA</b> <b>SCIENTIST</b></a>,
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/The-Home-Depot" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=ed17685d2e969f9b&amp;jcid=16ef23d67d728b35')" target="_blank">\n        Home Depot</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/The-Home-Depot/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=DATA+SCIENTIST&amp;fromjk=ed17685d2e969f9b&amp;jcid=16ef23d67d728b35');" target="_blank" title="Home Depot reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 43.8px;"><!-- --></span></span><span class="slNoUnderline">21,066 reviews</span></a>,
#  <a class="jobtitle turnstileLink" data-tn-element="jobTitle" href="/pagead/clk?mo=r&amp;ad=-6NYlbfkN0Aqmv_5JD5v6gg1ICRL12VY6BolF0XAUkQtat1DEGOKAas7v4hqpX3lzUM4h7L4VGsyuyDvf1POStkSJgHsuP2fB8YliLIijj53wvHBII5P9eQQwhBoT2Vrz0Dv0LOR9cmhA2uclIYN05H0FXZOFBhD9nFyVh6o8Pj-jnxI3CbMISVeGeVDBCyxVR6yZuCFehgzktgysMGHUL-roVmwC2j3G80RFSqE-aBVW-JwUn0q6sLZozKRnBJJ4b5KYlJZmo1SII-gap5KxPAM8P9ibOzHhWGm1yjZNRBfSyc5I9IEqCnncYFpPOaRlb0RRWUq_Xvzpxcp1QFJJ7yPWOiIP7I5hO-tGTA_DvRw-uLskag6uqVcIlw3k5alpzn5GN8E0spNHKdz7vvWtgWtmld8vURbi_1dAAo3asIRod6Vk_18cR6MWQ9TQtrhZUsOogVf3BM9Ysnd2hqYSPUA6zwf4w9469LugJJXK9Y=&amp;p=5&amp;sk=&amp;fvj=0" id="sja5" onclick="setRefineByCookie([]); sjoc('sja5',0); convCtr('SJ', pingUrlsForGA)" onmousedown="sjomd('sja5'); clk('sja5');" rel="nofollow" target="_blank" title="Data Scientist"><b>Data</b> <b>Scientist</b></a>,
#  <a class="turnstileLink" data-tn-element="companyName" href="/cmp/Cox-Automotive" onmousedown="this.href = appendParamsOnce(this.href, 'from=SERP&amp;campaignid=serp-linkcompanyname&amp;fromjk=4dd0428a36b610d7&amp;jcid=7e465a3d521b3ac3')" target="_blank">\n        Cox Automotive</a>,
#  <a class="turnstileLink slNoUnderline " data-tn-element="reviewStars" data-tn-variant="cmplinktst2" href="/cmp/Cox-Automotive/reviews" onmousedown="this.href = appendParamsOnce(this.href, '?campaignid=cmplinktst2&amp;from=SERP&amp;jt=Data+Scientist&amp;fromjk=4dd0428a36b610d7&amp;jcid=7e465a3d521b3ac3');" target="_blank" title="Cox Automotive reviews">\n<span class="ratings" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;width: 60px;"><span class="rating" style="height: 11px; line-height: 11px; background-image: url(/images/cmp/star_2_sm@2x.png); background-size: 12px 22px;background-position: 0 11px; width: 40.8px;"><!-- --></span></span><span class="slNoUnderline">46 reviews</span></a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=10"><span class="pn">2</span></a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=20"><span class="pn">3</span></a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=30"><span class="pn">4</span></a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=40"><span class="pn">5</span></a>,
#  <a href="/jobs?q=Data+Scientist&amp;l=Atlanta%2C+GA&amp;start=10&amp;pp="><span class="pn"><span class="np">Next\xa0\xbb</span></span></a>,
#  <a href="/q-Accounting-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">accounting</a>,
#  <a href="/q-Part-Time-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">part time</a>,
#  <a href="/q-Clerical-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">clerical</a>,
#  <a href="/q-Call-Center-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">call center</a>,
#  <a href="/q-Construction-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">construction</a>,
#  <a href="/q-Data-Entry-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">data entry</a>,
#  <a href="/q-Graphic-Design-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">graphic design</a>,
#  <a href="/q-Human-Resources-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">human resources</a>,
#  <a href="/q-Insurance-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">insurance</a>,
#  <a href="/q-Marketing-l-Atlanta,-GA-jobs.html?from=relatedQueries&amp;rqf=1&amp;parentQnorm=Data+Scientist">marketing</a>,
#  <a href="/forum/job/Statistician.html" onclick="logRSC('rfsclk', 'Statistician', '1b1pgpoona4clbpa')">Statistician</a>,
#  <a href="/forum/job/Quantitative-Analyst.html" onclick="logRSC('rfsclk', 'Quantitative Analyst', '1b1pgpoona4clbpa')">Quantitative Analyst</a>,
#  <a href="/forum/loc/Atlanta-Georgia.html" onclick="logRSC('rfsclk', 'Atlanta, Georgia', '1b1pgpoona4clbpa')">Atlanta, Georgia</a>,
#  <a href="/salary?q1=Statistician&amp;l1=Atlanta%2C+GA" onclick="logRSC('rssclk', 'Statistician', '1b1pgpoona4clbpa')">Statistician salary</a>,
#  <a href="/salary?q1=Quantitative+Analyst&amp;l1=Atlanta%2C+GA" onclick="logRSC('rssclk', 'Quantitative Analyst', '1b1pgpoona4clbpa')">Quantitative Analyst salary</a>,
#  <a href="/cmp/Cox-Automotive" onmousedown="this.href = appendParamsOnce(this.href, 'tk=1b1pgpoona4clbpa&amp;campaignid=femp&amp;from=femp');" target="_blank">\n<img alt="Cox Automotive" src="https://d2q79iu7y748jz.cloudfront.net/s/_logo/1979a083e8e37af435309c42a03e9ed4" width="120"/>\n</a>,
#  <a class="femp_cmp_link" href="/cmp/Cox-Automotive" onmousedown="this.href = appendParamsOnce(this.href, 'tk=1b1pgpoona4clbpa&amp;campaignid=femp&amp;from=femp');" target="_blank">\n            Cox Automotive</a>,
#  <a href="/jobs?q=company%3A%22Cox+Automotive%22&amp;l=Atlanta%2C+GA" onmousedown="this.href = appendParamsOnce(this.href, '&amp;from=femp');">Jobs (105)</a>,
#  <a href="/cmp/Cox-Automotive/reviews" onmousedown="this.href = appendParamsOnce(this.href, '&amp;campaignid=femp&amp;from=femp');">Reviews (46)</a>,
#  <a class="roundedCorner indeedblue" href="/promo/prime" id="learnMore" onclick="this.href = appendParamsOnce( this.href, '?from=primepopover&amp;subfrom=primepopover&amp;trk.origin=jobsearch&amp;trk.variant=primepopover&amp;trk.tk=1b1pgpoksa4cl8m2&amp;vertical=TECH&amp;x_isid=primepopover&amp;x_ikw=Data+Scientist')" role="button">Learn More</a>,
#  <a class="sl" href="/promo/gotajob" onmousedown="this.href = appendParamsOnce( this.href, '?trk.origin=jobsearch&amp;trk.tk=1b1pgpoona4clbpa')">Over 2.8 million stories shared</a>,
#  <a href="/" id="jobs_product_link" title="Jobs">Jobs</a>,
#  <a href="/Best-Places-to-Work" id="companies_product_link" title="Browse Companies">Browse Companies</a>,
#  <a href="/salary" id="salaries_product_link" title="Salary Search">Salaries</a>,
#  <a href="/jobtrends" id="trends_product_link" title="Career Trends">Trends</a>,
#  <a href="/forum" id="forums_product_link" title="Employment Forums">Forums</a>,
#  <a href="/find-jobs.jsp">Browse Jobs</a>,
#  <a href="/tools/jobseeker/">Tools</a>,
#  <a href="http://www.indeed.jobs">Work at Indeed</a>,
#  <a href="/publisher">API</a>,
#  <a href="/intl/en/about.html"><nobr>About</nobr></a>,
#  <a href="https://indeed.zendesk.com/hc/en-us">Help Center</a>,
#  <a href="/legal">Cookies, Privacy and Terms</a>]

# %%
for link in soup.find_all('a'):
    print link.get('href')
# Out:
# #jobPostingsAnchor
# #what
# None
# /
# /resumes?isid=find-resumes&ikw=SERPtop&co=US&hl=en
# /hire?hl=en&cc=US
# /promo/resume
# http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3DData%2BScientist%26l%3DAtlanta%2C%2BGA
# /
# /advanced_search?q=Data+Scientist&l=Atlanta%2C+GA
# /jobs?q=Data+Scientist&l=Atlanta%2C+GA&sort=date
# /q-Data-Scientist-$55,000-l-Atlanta,-GA-jobs.html
# /q-Data-Scientist-$70,000-l-Atlanta,-GA-jobs.html
# /q-Data-Scientist-$85,000-l-Atlanta,-GA-jobs.html
# /q-Data-Scientist-$100,000-l-Atlanta,-GA-jobs.html
# /q-Data-Scientist-$115,000-l-Atlanta,-GA-jobs.html
# /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=fulltime
# /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=contract
# /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=internship
# /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=parttime
# /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=commission
# /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=temporary
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Atlanta,+GA&jlid=966e6327a98f7e81
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Alpharetta,+GA&jlid=136fb7555504878c
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Duluth,+GA&jlid=ed96b91845c744fe
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Marietta,+GA&jlid=528fb8dbaacbeb3b
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Norcross,+GA&jlid=61b742028b096345
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Berkeley+Lake,+GA&jlid=1b2f56c7228d460f
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Johns+Creek,+GA&jlid=b258b190889f0f22
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Decatur,+GA&jlid=f9ba64383bdcdb29
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Smyrna,+GA&jlid=254cfc0ab0df7665
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Stone+Mountain,+GA&jlid=24923703f25e1c15
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Roswell,+GA&jlid=abf990a05b719190
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Kennesaw,+GA&jlid=382ecefe55e0ce93
# /q-Data-Scientist-jobs.html
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=ADP&jcid=e996c2d6855fe778
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Georgia+Tech+Research+Institute&jcid=d9c58fbcc2c9bece
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Children%27s+Healthcare+of+Atlanta&jcid=5d7180a195e12cf4
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Oak+Ridge+Associated+Universities&jcid=9bde7059673c2cbc
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Centers+for+Disease+Control+and+Prevention&jcid=3e901f592b439cea
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=KPMG&jcid=2dd390c3a48a7ed0
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=GE+Power&jcid=36cd83a149f09757
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Honeywell&jcid=50208b5bf45ee3b8
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Georgia+Tech&jcid=db25687464a9ecf6
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Emory+University&jcid=efe5e2d22a1d29e5
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Reed+Elsevier&jcid=f7a0f0e88ce3d78e
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Equifax&jcid=34c446722f3cf576
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=ICF&jcid=cc35f9c14f8799a9
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=AT%26T&jcid=25b5166547bbf543
# /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Home+Depot&jcid=16ef23d67d728b35
# /jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=mid_level
# /jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=entry_level
# /jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=senior_level
# /promo/prime
# None
# /pagead/clk?mo=r&ad=-6NYlbfkN0AbexXlh6WlNaC12RNLKcRQH8fywLm61v9KQllly0vTVrm9U0Iy0AOsYwOq9YOpDX03iprvWHw_SY6xCXG90mwLvOd8fb5BdJ-fu_-2tfp_KoWry1hPm7FaVRyBGPoeYEaNltu7W5i0j7KlWZFPmjLgIWx7L0bFO3kcNnufTddaPcPcV082PCVLmtiO_gyjP5gFnbtJj9GkA18deOm7BUQ0am2kTh-5rnprLl8sW589sA1w53JEauGHLmIfOZq04N98GivGmhlR-hxB6lwRkUZWzZOmHIdil7qIRSWrkC_monBcQ2wvbCJ8XUUr5FCwLNts-NXWaBzHtzhCoa6fFkV1G76AnCf3hxVnt5eLPzzGrTCZ3kNaEM49ZYMRwYjX8HUOsjrJpTE5TDrYJg7qf4vU_H8hGi-AF6URkOUThbwJwruOBLhsdB_IA0dnK4JHNENFtMqis9ylt63uSuhgN0Mw&p=1&sk=&fvj=0
# /cmp/Cotiviti
# /cmp/Cotiviti/reviews
# /pagead/clk?mo=r&ad=-6NYlbfkN0ADQeWqYYwuRDGK7FTA-YzU7Qag1HzehP-FB7aWzkBO6FRyVCTNkBclA9FrQyCAXLjn4u9IP3mepDeJnt-BtuBzfosurWUx8dMI4PS2dnzCGDjcb1rqHXIXHxiVvQw9rfF11WZQLdcQkIzgltmPYW2VvburimlHlkyDe_B_oHUYECMKEjBspsWtp3Q3HXZX2ldmjzaf3Pl0W1SUQWeOTehXzioQffBFoy_bLgTc4p96VXojEChOjrJ7bnRWuW76C17FN_y1xORn9gxfh72Cea0uuJpSTvDAOaFzFr-jBhg2lYfT-IowonC3j0c09SkgDXIDJlgD9mnxFplaPnEm9XZCozK6CEk23fzdVCZNcY2UD62tRTmScY8VaNVgMfabc6u4-xrNvjchT8zzXQVOsqR_2mJzF6ZV2Y8KKdnWstkepYM2TYTmB8ESfc7JyCaitJdsGHK5qe1GMQ==&p=2&sk=&fvj=1
# /pagead/clk?mo=r&ad=-6NYlbfkN0Bcgobz-t7weSGYTjoRWMIqcV9t0akB45B3k8NFJVZb5kkFpxn8bhfjltbVDjvx0bn0noTLqpSBW77839Ubfh4eL2ZvByfFlPegJkfgxbap4qbKzQXknClXAKQmaD18uRE6WyuXyxO_e8fzaqQSa7ZpxGZdW1QTr8PcL2Bkb24IpMS8LEQEQJPDWDX6LECH9ECkPSzAuxndU83nIA26ZgbZgH86G_X92KoN901nIKR14nUpH9Aln800WvE6PbZ8uQkL379Ds8upAIGVFRFz3AOC7Y4vkDoYXejADzEb41HfvTuFicGrbQBCEZsfw_Xchn7097dG8B6URhozWGeiuegsxwZUa4ga8_LJiiwo8NH8nVTxr3a4IbkEbx0h6bQ8iU4lOrYll-65kJiYkVuJTg77VK-OO5DunG0=&p=3&sk=&fvj=0
# /company/Vision3-Solutions,-Inc/jobs/Data-Scientist-1a8c086f5f6f1294?r=1&fccid=37d33d67f3fba52b
# #
# #
# #
# /jobs?q=Vision3+Solutions,+Inc&l=Atlanta,+GA&nc=jasx
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# /cmp/Vision3-Solutions,-Inc
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Vision3-Solutions%2C-Inc.html
# /company/FraudScope/jobs/Data-Scientist-d72c337465398caf?r=1&fccid=e87f46501099545c
# #
# #
# #
# /q-Fraudscope-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# /cmp/Fraudscope-1
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Fraudscope-1.html
# /rc/clk?jk=d21cbd39fb6dd414&fccid=25b5166547bbf543
# /cmp/AT&T
# /cmp/AT&T/reviews
# #
# #
# #
# /q-AT&T-l-Alpharetta,-GA-jobs.html
# /l-Alpharetta,-GA-jobs.html
# /salary?q1=AT%26T+Professional+Data+Scientist&l1=Alpharetta%2C+GA
# /cmp/AT&T
# /forum/loc/Alpharetta-Georgia.html
# /forum/cmp/AT%26T.html
# /rc/clk?jk=4a4948fe135cb354&fccid=cc35f9c14f8799a9
# /cmp/Icf
# /cmp/Icf/reviews
# #
# #
# #
# /q-Icf-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Scientific+Data+Analyst&l1=Atlanta%2C+GA
# /cmp/Icf
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Icf.html
# /rc/clk?jk=a959ea9503eb0043&fccid=11619ce0d3c2c733
# /cmp/Northrop-Grumman
# /cmp/Northrop-Grumman/reviews
# #
# #
# #
# /q-Northrop-Grumman-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Scientific+Data+Analyst&l1=Atlanta%2C+GA
# /cmp/Northrop-Grumman
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Northrop-Grumman.html
# /rc/clk?jk=cf742a5180d45499&fccid=ddf188c30da34688
# /cmp/Infor
# /cmp/Infor/reviews
# #
# #
# #
# /q-Infor-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Senior+Data+Scientist&l1=Atlanta%2C+GA
# /cmp/Infor
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Infor.html
# /rc/clk?jk=ece5708bd668a5e5&fccid=bd2e17bd9d57178b
# /cmp/Ignitionone
# /cmp/Ignitionone/reviews
# #
# #
# #
# /q-Ignitionone-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# /cmp/Ignitionone
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Ignitionone.html
# /company/Ashton212/jobs/Quantitative-Analyst-01ad090d112dbb83?r=1&fccid=f0461620810fcde2
# #
# #
# #
# /q-Ashton212-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Quantitative+Analyst&l1=Atlanta%2C+GA
# /cmp/Ashton212
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Ashton212.html
# /forum/job/Quantitative-Analyst.html
# /rc/clk?jk=8b1060b171ddf805&fccid=6df24d87c9f05a07
# /cmp/Macy's
# /cmp/Macy's/reviews
# #
# #
# #
# /jobs?q=Macy%27s&l=Atlanta,+GA
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# /cmp/Macy's
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Macy%27s.html
# /rc/clk?jk=1ae9fbf052162ca0&fccid=3e901f592b439cea
# /cmp/Centers-For-Disease-Control-and-Prevention
# /cmp/Centers-For-Disease-Control-and-Prevention/reviews
# #
# #
# #
# /q-Centers-For-Disease-Control-Prevention-l-Atlanta,-GA-jobs.html
# /l-Atlanta,-GA-jobs.html
# /salary?q1=Statistician&l1=Atlanta%2C+GA
# /cmp/Centers-For-Disease-Control-and-Prevention
# /forum/loc/Atlanta-Georgia.html
# /forum/cmp/Centers-For-Disease-Control-and-Prevention.html
# /forum/job/Statistician.html
# /pagead/clk?mo=r&ad=-6NYlbfkN0BOtxtSuljPipcOqTsdGhy_ryU9_Bpcutm1h1zAeyLmGnpluTyzXEqsxsrMKBlkufFESLwSdxJSAONzh1zkMDi4o-Ahekc18NAvrbyd8GeyF0DRrENb1LzCRVsYrK8Sg_PhO3N5J8mMNMCHG7w2soKtDolHAWh8bQLx4kgUx-edDWDbopKNxeouEV7g13l_uJJCj_WEQDH0ch1-XGO38Mv0osPvhW-UtWERAcFeRlYk4Iu1K_CXhk8QhINCqcWRGslagQ_CWyuz7tj2JQ02XrJQEEsF8P9VpQIYZo5GA_InsjLiwn3Rw2rSFwB-f9UvPji57Z6km78QBkeiXZJk0UumBK7RZsEteEnFRleBcnOKlM0TbhebkriFTWlaArxd9tkbZnr1xU2nMVXHhLhzS3MOIz7PAtQLv2WKiSJil9ot6S9jqvQ_QBFzznHSseOBPnPdV_zwR01qpRxeBwcKXi4X5ck2V-10RHWAqDPJWtwHr_dvWAqpNSARbS7oQwJEmg9vM_g_z2lk6vZqhnhRa7x74iv-mIDeBXV2H_hpXR2BOZROMCao81gVb_PWx5XFe-kiJPwC_NBTE4kjrmOHdDAXd1WW1E3AmnA5yUOC775bpqrG6M-xOjCS3LAi23FLikdyeRx9u3SM2MzlctJUOslzZlT-uMg_oA-BawRylH5DS-IsCsqBJ1E2EOwCrIRqSD90eMDrt--HjsdhbeOL7qw2MfMJ-W28iHZBsI25hooPF4W5CdOV3cqTXwCqledtYFD762mbFaNQIqGpbjlMlJGUoQ-6462ihKI=&p=4&sk=&fvj=0
# /cmp/The-Home-Depot
# /cmp/The-Home-Depot/reviews
# /pagead/clk?mo=r&ad=-6NYlbfkN0Aqmv_5JD5v6gg1ICRL12VY6BolF0XAUkQtat1DEGOKAas7v4hqpX3lzUM4h7L4VGsyuyDvf1POStkSJgHsuP2fB8YliLIijj53wvHBII5P9eQQwhBoT2Vrz0Dv0LOR9cmhA2uclIYN05H0FXZOFBhD9nFyVh6o8Pj-jnxI3CbMISVeGeVDBCyxVR6yZuCFehgzktgysMGHUL-roVmwC2j3G80RFSqE-aBVW-JwUn0q6sLZozKRnBJJ4b5KYlJZmo1SII-gap5KxPAM8P9ibOzHhWGm1yjZNRBfSyc5I9IEqCnncYFpPOaRlb0RRWUq_Xvzpxcp1QFJJ7yPWOiIP7I5hO-tGTA_DvRw-uLskag6uqVcIlw3k5alpzn5GN8E0spNHKdz7vvWtgWtmld8vURbi_1dAAo3asIRod6Vk_18cR6MWQ9TQtrhZUsOogVf3BM9Ysnd2hqYSPUA6zwf4w9469LugJJXK9Y=&p=5&sk=&fvj=0
# /cmp/Cox-Automotive
# /cmp/Cox-Automotive/reviews
# /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=10
# /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=20
# /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=30
# /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=40
# /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=10&pp=
# /q-Accounting-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Part-Time-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Clerical-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Call-Center-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Construction-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Data-Entry-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Graphic-Design-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Human-Resources-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Insurance-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /q-Marketing-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# /forum/job/Statistician.html
# /forum/job/Quantitative-Analyst.html
# /forum/loc/Atlanta-Georgia.html
# /salary?q1=Statistician&l1=Atlanta%2C+GA
# /salary?q1=Quantitative+Analyst&l1=Atlanta%2C+GA
# /cmp/Cox-Automotive
# /cmp/Cox-Automotive
# /jobs?q=company%3A%22Cox+Automotive%22&l=Atlanta%2C+GA
# /cmp/Cox-Automotive/reviews
# /promo/prime
# /promo/gotajob
# /
# /Best-Places-to-Work
# /salary
# /jobtrends
# /forum
# /find-jobs.jsp
# /tools/jobseeker/
# http://www.indeed.jobs
# /publisher
# /intl/en/about.html
# https://indeed.zendesk.com/hc/en-us
# /legal

# %%
for link in soup.find_all('a'):
    print link.text
# Out:
# Job Postings
# Search
# Close
# Find Jobs
# Find Resumes
# Employers / Post Job
# Upload your resume
# Sign in
#
# Advanced Job Search
# date
# $55,000+
# $70,000+
# $85,000+
# $100,000+
# $115,000+
# Full-time
# Contract
# Internship
# Part-time
# Commission
# Temporary
# Atlanta, GA
# Alpharetta, GA
# Duluth, GA
# Marietta, GA
# Norcross, GA
# Berkeley Lake, GA
# Johns Creek, GA
# Decatur, GA
# Smyrna, GA
# Stone Mountain, GA
# Roswell, GA
# Kennesaw, GA
# Data Scientist jobs
# ADP
# Georgia Tech Research Institute
# Children's Healthcare of Atlanta
# Oak Ridge Associated Universities
# Centers for Disease Control and Prevention
# KPMG
# GE Power
# Honeywell
# Georgia Tech
# Emory University
# Reed Elsevier
# Equifax
# ICF
# AT&T
# Home Depot
# Mid Level
# Entry Level
# Senior Level
# Join Indeed Prime
#
# Data Scientist
#
#         Cotiviti
#
# 30 reviews
# Data Scientist With Predictive Modeling
# Data Scientist
# Data Scientist- Big Data
# save job
# more...
#
# Vision3 Solutions, Inc jobs in Atlanta, GA
# Atlanta jobs
# Data Scientist salaries in Atlanta, GA
# Vision3 Solutions, Inc
# Atlanta, Georgia
# Vision3 Solutions, Inc
# Data Scientist
# save job
# more...
#
# FraudScope jobs in Atlanta, GA
# Atlanta jobs
# Data Scientist salaries in Atlanta, GA
# Fraudscope
# Atlanta, Georgia
# FraudScope
# AT&T Professional Data Scientist Alpharetta GA
#
#         AT&T
#
# 14,560 reviews
# save job
# more...
#
# AT&T jobs in Alpharetta, GA
# Alpharetta jobs
# AT&T Professional Data Scientist salaries in Alpharetta, GA
# AT&T
# Alpharetta, Georgia
# AT&T
# Scientific Data Analyst
#
#         ICF
#
# 235 reviews
# save job
# more...
#
# ICF jobs in Atlanta, GA
# Atlanta jobs
# Scientific Data Analyst salaries in Atlanta, GA
# Icf
# Atlanta, Georgia
# ICF
# Scientific Data Analyst
#
#         Northrop Grumman
#
# 2,159 reviews
# save job
# more...
#
# Northrop Grumman jobs in Atlanta, GA
# Atlanta jobs
# Scientific Data Analyst salaries in Atlanta, GA
# Northrop Grumman
# Atlanta, Georgia
# Northrop Grumman
# Sr. Data Scientist
#
#         Infor
#
# 62 reviews
# save job
# more...
#
# Infor jobs in Atlanta, GA
# Atlanta jobs
# Senior Data Scientist salaries in Atlanta, GA
# Infor
# Atlanta, Georgia
# Infor
# Data Scientist
#
#         IgnitionOne
#
# 8 reviews
# save job
# more...
#
# IgnitionOne jobs in Atlanta, GA
# Atlanta jobs
# Data Scientist salaries in Atlanta, GA
# Ignitionone
# Atlanta, Georgia
# IgnitionOne
# Quantitative Analyst | #769
# save job
# more...
#
# Ashton212 jobs in Atlanta, GA
# Atlanta jobs
# Quantitative Analyst salaries in Atlanta, GA
# Ashton212
# Atlanta, Georgia
# Ashton212
# Quantitative Analyst
# Data Scientist
#
#         Macy's
#
# 14,441 reviews
# save job
# more...
#
# Macy's jobs in Atlanta, GA
# Atlanta jobs
# Data Scientist salaries in Atlanta, GA
# Macy's
# Atlanta, Georgia
# Macy's
# Statistician (Health)
#
#         Centers for Disease Control and Prevention
#
# 66 reviews
# save job
# more...
#
# Centers for Disease Control and Prevention jobs in Atlanta, GA
# Atlanta jobs
# Statistician salaries in Atlanta, GA
# Centers For Disease Control and Prevention
# Atlanta, Georgia
# Centers for Disease Control and Prevention
# Statistician
# DATA SCIENTIST
#
#         Home Depot
#
# 21,066 reviews
# Data Scientist
#
#         Cox Automotive
#
# 46 reviews
# 2
# 3
# 4
# 5
# Next »
# accounting
# part time
# clerical
# call center
# construction
# data entry
# graphic design
# human resources
# insurance
# marketing
# Statistician
# Quantitative Analyst
# Atlanta, Georgia
# Statistician salary
# Quantitative Analyst salary
#
#
#
#
#             Cox Automotive
# Jobs (105)
# Reviews (46)
# Learn More
# Over 2.8 million stories shared
# Jobs
# Browse Companies
# Salaries
# Trends
# Forums
# Browse Jobs
# Tools
# Work at Indeed
# API
# About
# Help Center
# Cookies, Privacy and Terms

# %%
for link in soup.find_all('a'):
    print link.text, link.get('href')
# Out:
# Job Postings #jobPostingsAnchor
# Search #what
# Close None
# Find Jobs /
# Find Resumes /resumes?isid=find-resumes&ikw=SERPtop&co=US&hl=en
# Employers / Post Job /hire?hl=en&cc=US
# Upload your resume /promo/resume
# Sign in http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3DData%2BScientist%26l%3DAtlanta%2C%2BGA
#  /
# Advanced Job Search /advanced_search?q=Data+Scientist&l=Atlanta%2C+GA
# date /jobs?q=Data+Scientist&l=Atlanta%2C+GA&sort=date
# $55,000+ /q-Data-Scientist-$55,000-l-Atlanta,-GA-jobs.html
# $70,000+ /q-Data-Scientist-$70,000-l-Atlanta,-GA-jobs.html
# $85,000+ /q-Data-Scientist-$85,000-l-Atlanta,-GA-jobs.html
# $100,000+ /q-Data-Scientist-$100,000-l-Atlanta,-GA-jobs.html
# $115,000+ /q-Data-Scientist-$115,000-l-Atlanta,-GA-jobs.html
# Full-time /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=fulltime
# Contract /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=contract
# Internship /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=internship
# Part-time /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=parttime
# Commission /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=commission
# Temporary /jobs?q=Data+Scientist&l=Atlanta,+GA&jt=temporary
# Atlanta, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Atlanta,+GA&jlid=966e6327a98f7e81
# Alpharetta, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Alpharetta,+GA&jlid=136fb7555504878c
# Duluth, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Duluth,+GA&jlid=ed96b91845c744fe
# Marietta, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Marietta,+GA&jlid=528fb8dbaacbeb3b
# Norcross, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Norcross,+GA&jlid=61b742028b096345
# Berkeley Lake, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Berkeley+Lake,+GA&jlid=1b2f56c7228d460f
# Johns Creek, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Johns+Creek,+GA&jlid=b258b190889f0f22
# Decatur, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Decatur,+GA&jlid=f9ba64383bdcdb29
# Smyrna, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Smyrna,+GA&jlid=254cfc0ab0df7665
# Stone Mountain, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Stone+Mountain,+GA&jlid=24923703f25e1c15
# Roswell, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Roswell,+GA&jlid=abf990a05b719190
# Kennesaw, GA /jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Kennesaw,+GA&jlid=382ecefe55e0ce93
# Data Scientist jobs /q-Data-Scientist-jobs.html
# ADP /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=ADP&jcid=e996c2d6855fe778
# Georgia Tech Research Institute /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Georgia+Tech+Research+Institute&jcid=d9c58fbcc2c9bece
# Children's Healthcare of Atlanta /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Children%27s+Healthcare+of+Atlanta&jcid=5d7180a195e12cf4
# Oak Ridge Associated Universities /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Oak+Ridge+Associated+Universities&jcid=9bde7059673c2cbc
# Centers for Disease Control and Prevention /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Centers+for+Disease+Control+and+Prevention&jcid=3e901f592b439cea
# KPMG /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=KPMG&jcid=2dd390c3a48a7ed0
# GE Power /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=GE+Power&jcid=36cd83a149f09757
# Honeywell /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Honeywell&jcid=50208b5bf45ee3b8
# Georgia Tech /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Georgia+Tech&jcid=db25687464a9ecf6
# Emory University /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Emory+University&jcid=efe5e2d22a1d29e5
# Reed Elsevier /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Reed+Elsevier&jcid=f7a0f0e88ce3d78e
# Equifax /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Equifax&jcid=34c446722f3cf576
# ICF /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=ICF&jcid=cc35f9c14f8799a9
# AT&T /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=AT%26T&jcid=25b5166547bbf543
# Home Depot /jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Home+Depot&jcid=16ef23d67d728b35
# Mid Level /jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=mid_level
# Entry Level /jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=entry_level
# Senior Level /jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=senior_level
# Join Indeed Prime /promo/prime
#  None
# Data Scientist /pagead/clk?mo=r&ad=-6NYlbfkN0AbexXlh6WlNaC12RNLKcRQH8fywLm61v9KQllly0vTVrm9U0Iy0AOsYwOq9YOpDX03iprvWHw_SY6xCXG90mwLvOd8fb5BdJ-fu_-2tfp_KoWry1hPm7FaVRyBGPoeYEaNltu7W5i0j7KlWZFPmjLgIWx7L0bFO3kcNnufTddaPcPcV082PCVLmtiO_gyjP5gFnbtJj9GkA18deOm7BUQ0am2kTh-5rnprLl8sW589sA1w53JEauGHLmIfOZq04N98GivGmhlR-hxB6lwRkUZWzZOmHIdil7qIRSWrkC_monBcQ2wvbCJ8XUUr5FCwLNts-NXWaBzHtzhCoa6fFkV1G76AnCf3hxVnt5eLPzzGrTCZ3kNaEM49ZYMRwYjX8HUOsjrJpTE5TDrYJg7qf4vU_H8hGi-AF6URkOUThbwJwruOBLhsdB_IA0dnK4JHNENFtMqis9ylt63uSuhgN0Mw&p=1&sk=&fvj=0
#
#         Cotiviti /cmp/Cotiviti
#
# 30 reviews /cmp/Cotiviti/reviews
# Data Scientist With Predictive Modeling /pagead/clk?mo=r&ad=-6NYlbfkN0ADQeWqYYwuRDGK7FTA-YzU7Qag1HzehP-FB7aWzkBO6FRyVCTNkBclA9FrQyCAXLjn4u9IP3mepDeJnt-BtuBzfosurWUx8dMI4PS2dnzCGDjcb1rqHXIXHxiVvQw9rfF11WZQLdcQkIzgltmPYW2VvburimlHlkyDe_B_oHUYECMKEjBspsWtp3Q3HXZX2ldmjzaf3Pl0W1SUQWeOTehXzioQffBFoy_bLgTc4p96VXojEChOjrJ7bnRWuW76C17FN_y1xORn9gxfh72Cea0uuJpSTvDAOaFzFr-jBhg2lYfT-IowonC3j0c09SkgDXIDJlgD9mnxFplaPnEm9XZCozK6CEk23fzdVCZNcY2UD62tRTmScY8VaNVgMfabc6u4-xrNvjchT8zzXQVOsqR_2mJzF6ZV2Y8KKdnWstkepYM2TYTmB8ESfc7JyCaitJdsGHK5qe1GMQ==&p=2&sk=&fvj=1
# Data Scientist /pagead/clk?mo=r&ad=-6NYlbfkN0Bcgobz-t7weSGYTjoRWMIqcV9t0akB45B3k8NFJVZb5kkFpxn8bhfjltbVDjvx0bn0noTLqpSBW77839Ubfh4eL2ZvByfFlPegJkfgxbap4qbKzQXknClXAKQmaD18uRE6WyuXyxO_e8fzaqQSa7ZpxGZdW1QTr8PcL2Bkb24IpMS8LEQEQJPDWDX6LECH9ECkPSzAuxndU83nIA26ZgbZgH86G_X92KoN901nIKR14nUpH9Aln800WvE6PbZ8uQkL379Ds8upAIGVFRFz3AOC7Y4vkDoYXejADzEb41HfvTuFicGrbQBCEZsfw_Xchn7097dG8B6URhozWGeiuegsxwZUa4ga8_LJiiwo8NH8nVTxr3a4IbkEbx0h6bQ8iU4lOrYll-65kJiYkVuJTg77VK-OO5DunG0=&p=3&sk=&fvj=0
# Data Scientist- Big Data /company/Vision3-Solutions,-Inc/jobs/Data-Scientist-1a8c086f5f6f1294?r=1&fccid=37d33d67f3fba52b
# save job #
# more... #
#  #
# Vision3 Solutions, Inc jobs in Atlanta, GA /jobs?q=Vision3+Solutions,+Inc&l=Atlanta,+GA&nc=jasx
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Data Scientist salaries in Atlanta, GA /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# Vision3 Solutions, Inc /cmp/Vision3-Solutions,-Inc
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Vision3 Solutions, Inc /forum/cmp/Vision3-Solutions%2C-Inc.html
# Data Scientist /company/FraudScope/jobs/Data-Scientist-d72c337465398caf?r=1&fccid=e87f46501099545c
# save job #
# more... #
#  #
# FraudScope jobs in Atlanta, GA /q-Fraudscope-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Data Scientist salaries in Atlanta, GA /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# Fraudscope /cmp/Fraudscope-1
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# FraudScope /forum/cmp/Fraudscope-1.html
# AT&T Professional Data Scientist Alpharetta GA /rc/clk?jk=d21cbd39fb6dd414&fccid=25b5166547bbf543
#
#         AT&T /cmp/AT&T
#
# 14,560 reviews /cmp/AT&T/reviews
# save job #
# more... #
#  #
# AT&T jobs in Alpharetta, GA /q-AT&T-l-Alpharetta,-GA-jobs.html
# Alpharetta jobs /l-Alpharetta,-GA-jobs.html
# AT&T Professional Data Scientist salaries in Alpharetta, GA /salary?q1=AT%26T+Professional+Data+Scientist&l1=Alpharetta%2C+GA
# AT&T /cmp/AT&T
# Alpharetta, Georgia /forum/loc/Alpharetta-Georgia.html
# AT&T /forum/cmp/AT%26T.html
# Scientific Data Analyst /rc/clk?jk=4a4948fe135cb354&fccid=cc35f9c14f8799a9
#
#         ICF /cmp/Icf
#
# 235 reviews /cmp/Icf/reviews
# save job #
# more... #
#  #
# ICF jobs in Atlanta, GA /q-Icf-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Scientific Data Analyst salaries in Atlanta, GA /salary?q1=Scientific+Data+Analyst&l1=Atlanta%2C+GA
# Icf /cmp/Icf
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# ICF /forum/cmp/Icf.html
# Scientific Data Analyst /rc/clk?jk=a959ea9503eb0043&fccid=11619ce0d3c2c733
#
#         Northrop Grumman /cmp/Northrop-Grumman
#
# 2,159 reviews /cmp/Northrop-Grumman/reviews
# save job #
# more... #
#  #
# Northrop Grumman jobs in Atlanta, GA /q-Northrop-Grumman-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Scientific Data Analyst salaries in Atlanta, GA /salary?q1=Scientific+Data+Analyst&l1=Atlanta%2C+GA
# Northrop Grumman /cmp/Northrop-Grumman
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Northrop Grumman /forum/cmp/Northrop-Grumman.html
# Sr. Data Scientist /rc/clk?jk=cf742a5180d45499&fccid=ddf188c30da34688
#
#         Infor /cmp/Infor
#
# 62 reviews /cmp/Infor/reviews
# save job #
# more... #
#  #
# Infor jobs in Atlanta, GA /q-Infor-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Senior Data Scientist salaries in Atlanta, GA /salary?q1=Senior+Data+Scientist&l1=Atlanta%2C+GA
# Infor /cmp/Infor
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Infor /forum/cmp/Infor.html
# Data Scientist /rc/clk?jk=ece5708bd668a5e5&fccid=bd2e17bd9d57178b
#
#         IgnitionOne /cmp/Ignitionone
#
# 8 reviews /cmp/Ignitionone/reviews
# save job #
# more... #
#  #
# IgnitionOne jobs in Atlanta, GA /q-Ignitionone-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Data Scientist salaries in Atlanta, GA /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# Ignitionone /cmp/Ignitionone
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# IgnitionOne /forum/cmp/Ignitionone.html
# Quantitative Analyst | #769 /company/Ashton212/jobs/Quantitative-Analyst-01ad090d112dbb83?r=1&fccid=f0461620810fcde2
# save job #
# more... #
#  #
# Ashton212 jobs in Atlanta, GA /q-Ashton212-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Quantitative Analyst salaries in Atlanta, GA /salary?q1=Quantitative+Analyst&l1=Atlanta%2C+GA
# Ashton212 /cmp/Ashton212
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Ashton212 /forum/cmp/Ashton212.html
# Quantitative Analyst /forum/job/Quantitative-Analyst.html
# Data Scientist /rc/clk?jk=8b1060b171ddf805&fccid=6df24d87c9f05a07
#
#         Macy's /cmp/Macy's
#
# 14,441 reviews /cmp/Macy's/reviews
# save job #
# more... #
#  #
# Macy's jobs in Atlanta, GA /jobs?q=Macy%27s&l=Atlanta,+GA
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Data Scientist salaries in Atlanta, GA /salary?q1=Data+Scientist&l1=Atlanta%2C+GA
# Macy's /cmp/Macy's
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Macy's /forum/cmp/Macy%27s.html
# Statistician (Health) /rc/clk?jk=1ae9fbf052162ca0&fccid=3e901f592b439cea
#
#         Centers for Disease Control and Prevention /cmp/Centers-For-Disease-Control-and-Prevention
#
# 66 reviews /cmp/Centers-For-Disease-Control-and-Prevention/reviews
# save job #
# more... #
#  #
# Centers for Disease Control and Prevention jobs in Atlanta, GA /q-Centers-For-Disease-Control-Prevention-l-Atlanta,-GA-jobs.html
# Atlanta jobs /l-Atlanta,-GA-jobs.html
# Statistician salaries in Atlanta, GA /salary?q1=Statistician&l1=Atlanta%2C+GA
# Centers For Disease Control and Prevention /cmp/Centers-For-Disease-Control-and-Prevention
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Centers for Disease Control and Prevention /forum/cmp/Centers-For-Disease-Control-and-Prevention.html
# Statistician /forum/job/Statistician.html
# DATA SCIENTIST /pagead/clk?mo=r&ad=-6NYlbfkN0BOtxtSuljPipcOqTsdGhy_ryU9_Bpcutm1h1zAeyLmGnpluTyzXEqsxsrMKBlkufFESLwSdxJSAONzh1zkMDi4o-Ahekc18NAvrbyd8GeyF0DRrENb1LzCRVsYrK8Sg_PhO3N5J8mMNMCHG7w2soKtDolHAWh8bQLx4kgUx-edDWDbopKNxeouEV7g13l_uJJCj_WEQDH0ch1-XGO38Mv0osPvhW-UtWERAcFeRlYk4Iu1K_CXhk8QhINCqcWRGslagQ_CWyuz7tj2JQ02XrJQEEsF8P9VpQIYZo5GA_InsjLiwn3Rw2rSFwB-f9UvPji57Z6km78QBkeiXZJk0UumBK7RZsEteEnFRleBcnOKlM0TbhebkriFTWlaArxd9tkbZnr1xU2nMVXHhLhzS3MOIz7PAtQLv2WKiSJil9ot6S9jqvQ_QBFzznHSseOBPnPdV_zwR01qpRxeBwcKXi4X5ck2V-10RHWAqDPJWtwHr_dvWAqpNSARbS7oQwJEmg9vM_g_z2lk6vZqhnhRa7x74iv-mIDeBXV2H_hpXR2BOZROMCao81gVb_PWx5XFe-kiJPwC_NBTE4kjrmOHdDAXd1WW1E3AmnA5yUOC775bpqrG6M-xOjCS3LAi23FLikdyeRx9u3SM2MzlctJUOslzZlT-uMg_oA-BawRylH5DS-IsCsqBJ1E2EOwCrIRqSD90eMDrt--HjsdhbeOL7qw2MfMJ-W28iHZBsI25hooPF4W5CdOV3cqTXwCqledtYFD762mbFaNQIqGpbjlMlJGUoQ-6462ihKI=&p=4&sk=&fvj=0
#
#         Home Depot /cmp/The-Home-Depot
#
# 21,066 reviews /cmp/The-Home-Depot/reviews
# Data Scientist /pagead/clk?mo=r&ad=-6NYlbfkN0Aqmv_5JD5v6gg1ICRL12VY6BolF0XAUkQtat1DEGOKAas7v4hqpX3lzUM4h7L4VGsyuyDvf1POStkSJgHsuP2fB8YliLIijj53wvHBII5P9eQQwhBoT2Vrz0Dv0LOR9cmhA2uclIYN05H0FXZOFBhD9nFyVh6o8Pj-jnxI3CbMISVeGeVDBCyxVR6yZuCFehgzktgysMGHUL-roVmwC2j3G80RFSqE-aBVW-JwUn0q6sLZozKRnBJJ4b5KYlJZmo1SII-gap5KxPAM8P9ibOzHhWGm1yjZNRBfSyc5I9IEqCnncYFpPOaRlb0RRWUq_Xvzpxcp1QFJJ7yPWOiIP7I5hO-tGTA_DvRw-uLskag6uqVcIlw3k5alpzn5GN8E0spNHKdz7vvWtgWtmld8vURbi_1dAAo3asIRod6Vk_18cR6MWQ9TQtrhZUsOogVf3BM9Ysnd2hqYSPUA6zwf4w9469LugJJXK9Y=&p=5&sk=&fvj=0
#
#         Cox Automotive /cmp/Cox-Automotive
#
# 46 reviews /cmp/Cox-Automotive/reviews
# 2 /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=10
# 3 /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=20
# 4 /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=30
# 5 /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=40
# Next » /jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=10&pp=
# accounting /q-Accounting-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# part time /q-Part-Time-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# clerical /q-Clerical-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# call center /q-Call-Center-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# construction /q-Construction-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# data entry /q-Data-Entry-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# graphic design /q-Graphic-Design-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# human resources /q-Human-Resources-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# insurance /q-Insurance-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# marketing /q-Marketing-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist
# Statistician /forum/job/Statistician.html
# Quantitative Analyst /forum/job/Quantitative-Analyst.html
# Atlanta, Georgia /forum/loc/Atlanta-Georgia.html
# Statistician salary /salary?q1=Statistician&l1=Atlanta%2C+GA
# Quantitative Analyst salary /salary?q1=Quantitative+Analyst&l1=Atlanta%2C+GA
#
#
# /cmp/Cox-Automotive
#
#             Cox Automotive /cmp/Cox-Automotive
# Jobs (105) /jobs?q=company%3A%22Cox+Automotive%22&l=Atlanta%2C+GA
# Reviews (46) /cmp/Cox-Automotive/reviews
# Learn More /promo/prime
# Over 2.8 million stories shared /promo/gotajob
# Jobs /
# Browse Companies /Best-Places-to-Work
# Salaries /salary
# Trends /jobtrends
# Forums /forum
# Browse Jobs /find-jobs.jsp
# Tools /tools/jobseeker/
# Work at Indeed http://www.indeed.jobs
# API /publisher
# About /intl/en/about.html
# Help Center https://indeed.zendesk.com/hc/en-us
# Cookies, Privacy and Terms /legal

# %%
for link in soup.find_all('a'):
    print "<a href = '%s'>%s</a>"%(link.get("href"), link.text)
# Out:
# <a href = '#jobPostingsAnchor'>Job Postings</a>
# <a href = '#what'>Search</a>
# <a href = 'None'>Close</a>
# <a href = '/'>Find Jobs</a>
# <a href = '/resumes?isid=find-resumes&ikw=SERPtop&co=US&hl=en'>Find Resumes</a>
# <a href = '/hire?hl=en&cc=US'>Employers / Post Job</a>
# <a href = '/promo/resume'>Upload your resume</a>
# <a href = 'http://www.indeed.com/account/login?dest=%2Fjobs%3Fq%3DData%2BScientist%26l%3DAtlanta%2C%2BGA'>Sign in</a>
# <a href = '/'></a>
# <a href = '/advanced_search?q=Data+Scientist&l=Atlanta%2C+GA'>Advanced Job Search</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta%2C+GA&sort=date'>date</a>
# <a href = '/q-Data-Scientist-$55,000-l-Atlanta,-GA-jobs.html'>$55,000+</a>
# <a href = '/q-Data-Scientist-$70,000-l-Atlanta,-GA-jobs.html'>$70,000+</a>
# <a href = '/q-Data-Scientist-$85,000-l-Atlanta,-GA-jobs.html'>$85,000+</a>
# <a href = '/q-Data-Scientist-$100,000-l-Atlanta,-GA-jobs.html'>$100,000+</a>
# <a href = '/q-Data-Scientist-$115,000-l-Atlanta,-GA-jobs.html'>$115,000+</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&jt=fulltime'>Full-time</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&jt=contract'>Contract</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&jt=internship'>Internship</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&jt=parttime'>Part-time</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&jt=commission'>Commission</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&jt=temporary'>Temporary</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Atlanta,+GA&jlid=966e6327a98f7e81'>Atlanta, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Alpharetta,+GA&jlid=136fb7555504878c'>Alpharetta, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Duluth,+GA&jlid=ed96b91845c744fe'>Duluth, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Marietta,+GA&jlid=528fb8dbaacbeb3b'>Marietta, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Norcross,+GA&jlid=61b742028b096345'>Norcross, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Berkeley+Lake,+GA&jlid=1b2f56c7228d460f'>Berkeley Lake, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Johns+Creek,+GA&jlid=b258b190889f0f22'>Johns Creek, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Decatur,+GA&jlid=f9ba64383bdcdb29'>Decatur, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Smyrna,+GA&jlid=254cfc0ab0df7665'>Smyrna, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Stone+Mountain,+GA&jlid=24923703f25e1c15'>Stone Mountain, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Roswell,+GA&jlid=abf990a05b719190'>Roswell, GA</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbl=Kennesaw,+GA&jlid=382ecefe55e0ce93'>Kennesaw, GA</a>
# <a href = '/q-Data-Scientist-jobs.html'>Data Scientist jobs</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=ADP&jcid=e996c2d6855fe778'>ADP</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Georgia+Tech+Research+Institute&jcid=d9c58fbcc2c9bece'>Georgia Tech Research Institute</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Children%27s+Healthcare+of+Atlanta&jcid=5d7180a195e12cf4'>Children's Healthcare of Atlanta</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Oak+Ridge+Associated+Universities&jcid=9bde7059673c2cbc'>Oak Ridge Associated Universities</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Centers+for+Disease+Control+and+Prevention&jcid=3e901f592b439cea'>Centers for Disease Control and Prevention</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=KPMG&jcid=2dd390c3a48a7ed0'>KPMG</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=GE+Power&jcid=36cd83a149f09757'>GE Power</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Honeywell&jcid=50208b5bf45ee3b8'>Honeywell</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Georgia+Tech&jcid=db25687464a9ecf6'>Georgia Tech</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Emory+University&jcid=efe5e2d22a1d29e5'>Emory University</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Reed+Elsevier&jcid=f7a0f0e88ce3d78e'>Reed Elsevier</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Equifax&jcid=34c446722f3cf576'>Equifax</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=ICF&jcid=cc35f9c14f8799a9'>ICF</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=AT%26T&jcid=25b5166547bbf543'>AT&T</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&rbc=Home+Depot&jcid=16ef23d67d728b35'>Home Depot</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=mid_level'>Mid Level</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=entry_level'>Entry Level</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta,+GA&explvl=senior_level'>Senior Level</a>
# <a href = '/promo/prime'>Join Indeed Prime</a>
# <a href = 'None'></a>
# <a href = '/pagead/clk?mo=r&ad=-6NYlbfkN0AbexXlh6WlNaC12RNLKcRQH8fywLm61v9KQllly0vTVrm9U0Iy0AOsYwOq9YOpDX03iprvWHw_SY6xCXG90mwLvOd8fb5BdJ-fu_-2tfp_KoWry1hPm7FaVRyBGPoeYEaNltu7W5i0j7KlWZFPmjLgIWx7L0bFO3kcNnufTddaPcPcV082PCVLmtiO_gyjP5gFnbtJj9GkA18deOm7BUQ0am2kTh-5rnprLl8sW589sA1w53JEauGHLmIfOZq04N98GivGmhlR-hxB6lwRkUZWzZOmHIdil7qIRSWrkC_monBcQ2wvbCJ8XUUr5FCwLNts-NXWaBzHtzhCoa6fFkV1G76AnCf3hxVnt5eLPzzGrTCZ3kNaEM49ZYMRwYjX8HUOsjrJpTE5TDrYJg7qf4vU_H8hGi-AF6URkOUThbwJwruOBLhsdB_IA0dnK4JHNENFtMqis9ylt63uSuhgN0Mw&p=1&sk=&fvj=0'>Data Scientist</a>
# <a href = '/cmp/Cotiviti'>
#         Cotiviti</a>
# <a href = '/cmp/Cotiviti/reviews'>
# 30 reviews</a>
# <a href = '/pagead/clk?mo=r&ad=-6NYlbfkN0ADQeWqYYwuRDGK7FTA-YzU7Qag1HzehP-FB7aWzkBO6FRyVCTNkBclA9FrQyCAXLjn4u9IP3mepDeJnt-BtuBzfosurWUx8dMI4PS2dnzCGDjcb1rqHXIXHxiVvQw9rfF11WZQLdcQkIzgltmPYW2VvburimlHlkyDe_B_oHUYECMKEjBspsWtp3Q3HXZX2ldmjzaf3Pl0W1SUQWeOTehXzioQffBFoy_bLgTc4p96VXojEChOjrJ7bnRWuW76C17FN_y1xORn9gxfh72Cea0uuJpSTvDAOaFzFr-jBhg2lYfT-IowonC3j0c09SkgDXIDJlgD9mnxFplaPnEm9XZCozK6CEk23fzdVCZNcY2UD62tRTmScY8VaNVgMfabc6u4-xrNvjchT8zzXQVOsqR_2mJzF6ZV2Y8KKdnWstkepYM2TYTmB8ESfc7JyCaitJdsGHK5qe1GMQ==&p=2&sk=&fvj=1'>Data Scientist With Predictive Modeling</a>
# <a href = '/pagead/clk?mo=r&ad=-6NYlbfkN0Bcgobz-t7weSGYTjoRWMIqcV9t0akB45B3k8NFJVZb5kkFpxn8bhfjltbVDjvx0bn0noTLqpSBW77839Ubfh4eL2ZvByfFlPegJkfgxbap4qbKzQXknClXAKQmaD18uRE6WyuXyxO_e8fzaqQSa7ZpxGZdW1QTr8PcL2Bkb24IpMS8LEQEQJPDWDX6LECH9ECkPSzAuxndU83nIA26ZgbZgH86G_X92KoN901nIKR14nUpH9Aln800WvE6PbZ8uQkL379Ds8upAIGVFRFz3AOC7Y4vkDoYXejADzEb41HfvTuFicGrbQBCEZsfw_Xchn7097dG8B6URhozWGeiuegsxwZUa4ga8_LJiiwo8NH8nVTxr3a4IbkEbx0h6bQ8iU4lOrYll-65kJiYkVuJTg77VK-OO5DunG0=&p=3&sk=&fvj=0'>Data Scientist</a>
# <a href = '/company/Vision3-Solutions,-Inc/jobs/Data-Scientist-1a8c086f5f6f1294?r=1&fccid=37d33d67f3fba52b'>Data Scientist- Big Data</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/jobs?q=Vision3+Solutions,+Inc&l=Atlanta,+GA&nc=jasx'>Vision3 Solutions, Inc jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Data+Scientist&l1=Atlanta%2C+GA'>Data Scientist salaries in Atlanta, GA</a>
# <a href = '/cmp/Vision3-Solutions,-Inc'>Vision3 Solutions, Inc</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Vision3-Solutions%2C-Inc.html'>Vision3 Solutions, Inc</a>
# <a href = '/company/FraudScope/jobs/Data-Scientist-d72c337465398caf?r=1&fccid=e87f46501099545c'>Data Scientist</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Fraudscope-l-Atlanta,-GA-jobs.html'>FraudScope jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Data+Scientist&l1=Atlanta%2C+GA'>Data Scientist salaries in Atlanta, GA</a>
# <a href = '/cmp/Fraudscope-1'>Fraudscope</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Fraudscope-1.html'>FraudScope</a>
# <a href = '/rc/clk?jk=d21cbd39fb6dd414&fccid=25b5166547bbf543'>AT&T Professional Data Scientist Alpharetta GA</a>
# <a href = '/cmp/AT&T'>
#         AT&T</a>
# <a href = '/cmp/AT&T/reviews'>
# 14,560 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-AT&T-l-Alpharetta,-GA-jobs.html'>AT&T jobs in Alpharetta, GA</a>
# <a href = '/l-Alpharetta,-GA-jobs.html'>Alpharetta jobs</a>
# <a href = '/salary?q1=AT%26T+Professional+Data+Scientist&l1=Alpharetta%2C+GA'>AT&T Professional Data Scientist salaries in Alpharetta, GA</a>
# <a href = '/cmp/AT&T'>AT&T</a>
# <a href = '/forum/loc/Alpharetta-Georgia.html'>Alpharetta, Georgia</a>
# <a href = '/forum/cmp/AT%26T.html'>AT&T</a>
# <a href = '/rc/clk?jk=4a4948fe135cb354&fccid=cc35f9c14f8799a9'>Scientific Data Analyst</a>
# <a href = '/cmp/Icf'>
#         ICF</a>
# <a href = '/cmp/Icf/reviews'>
# 235 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Icf-l-Atlanta,-GA-jobs.html'>ICF jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Scientific+Data+Analyst&l1=Atlanta%2C+GA'>Scientific Data Analyst salaries in Atlanta, GA</a>
# <a href = '/cmp/Icf'>Icf</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Icf.html'>ICF</a>
# <a href = '/rc/clk?jk=a959ea9503eb0043&fccid=11619ce0d3c2c733'>Scientific Data Analyst</a>
# <a href = '/cmp/Northrop-Grumman'>
#         Northrop Grumman</a>
# <a href = '/cmp/Northrop-Grumman/reviews'>
# 2,159 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Northrop-Grumman-l-Atlanta,-GA-jobs.html'>Northrop Grumman jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Scientific+Data+Analyst&l1=Atlanta%2C+GA'>Scientific Data Analyst salaries in Atlanta, GA</a>
# <a href = '/cmp/Northrop-Grumman'>Northrop Grumman</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Northrop-Grumman.html'>Northrop Grumman</a>
# <a href = '/rc/clk?jk=cf742a5180d45499&fccid=ddf188c30da34688'>Sr. Data Scientist</a>
# <a href = '/cmp/Infor'>
#         Infor</a>
# <a href = '/cmp/Infor/reviews'>
# 62 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Infor-l-Atlanta,-GA-jobs.html'>Infor jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Senior+Data+Scientist&l1=Atlanta%2C+GA'>Senior Data Scientist salaries in Atlanta, GA</a>
# <a href = '/cmp/Infor'>Infor</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Infor.html'>Infor</a>
# <a href = '/rc/clk?jk=ece5708bd668a5e5&fccid=bd2e17bd9d57178b'>Data Scientist</a>
# <a href = '/cmp/Ignitionone'>
#         IgnitionOne</a>
# <a href = '/cmp/Ignitionone/reviews'>
# 8 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Ignitionone-l-Atlanta,-GA-jobs.html'>IgnitionOne jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Data+Scientist&l1=Atlanta%2C+GA'>Data Scientist salaries in Atlanta, GA</a>
# <a href = '/cmp/Ignitionone'>Ignitionone</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Ignitionone.html'>IgnitionOne</a>
# <a href = '/company/Ashton212/jobs/Quantitative-Analyst-01ad090d112dbb83?r=1&fccid=f0461620810fcde2'>Quantitative Analyst | #769</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Ashton212-l-Atlanta,-GA-jobs.html'>Ashton212 jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Quantitative+Analyst&l1=Atlanta%2C+GA'>Quantitative Analyst salaries in Atlanta, GA</a>
# <a href = '/cmp/Ashton212'>Ashton212</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Ashton212.html'>Ashton212</a>
# <a href = '/forum/job/Quantitative-Analyst.html'>Quantitative Analyst</a>
# <a href = '/rc/clk?jk=8b1060b171ddf805&fccid=6df24d87c9f05a07'>Data Scientist</a>
# <a href = '/cmp/Macy's'>
#         Macy's</a>
# <a href = '/cmp/Macy's/reviews'>
# 14,441 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/jobs?q=Macy%27s&l=Atlanta,+GA'>Macy's jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Data+Scientist&l1=Atlanta%2C+GA'>Data Scientist salaries in Atlanta, GA</a>
# <a href = '/cmp/Macy's'>Macy's</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Macy%27s.html'>Macy's</a>
# <a href = '/rc/clk?jk=1ae9fbf052162ca0&fccid=3e901f592b439cea'>Statistician (Health)</a>
# <a href = '/cmp/Centers-For-Disease-Control-and-Prevention'>
#         Centers for Disease Control and Prevention</a>
# <a href = '/cmp/Centers-For-Disease-Control-and-Prevention/reviews'>
# 66 reviews</a>
# <a href = '#'>save job</a>
# <a href = '#'>more...</a>
# <a href = '#'></a>
# <a href = '/q-Centers-For-Disease-Control-Prevention-l-Atlanta,-GA-jobs.html'>Centers for Disease Control and Prevention jobs in Atlanta, GA</a>
# <a href = '/l-Atlanta,-GA-jobs.html'>Atlanta jobs</a>
# <a href = '/salary?q1=Statistician&l1=Atlanta%2C+GA'>Statistician salaries in Atlanta, GA</a>
# <a href = '/cmp/Centers-For-Disease-Control-and-Prevention'>Centers For Disease Control and Prevention</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/forum/cmp/Centers-For-Disease-Control-and-Prevention.html'>Centers for Disease Control and Prevention</a>
# <a href = '/forum/job/Statistician.html'>Statistician</a>
# <a href = '/pagead/clk?mo=r&ad=-6NYlbfkN0BOtxtSuljPipcOqTsdGhy_ryU9_Bpcutm1h1zAeyLmGnpluTyzXEqsxsrMKBlkufFESLwSdxJSAONzh1zkMDi4o-Ahekc18NAvrbyd8GeyF0DRrENb1LzCRVsYrK8Sg_PhO3N5J8mMNMCHG7w2soKtDolHAWh8bQLx4kgUx-edDWDbopKNxeouEV7g13l_uJJCj_WEQDH0ch1-XGO38Mv0osPvhW-UtWERAcFeRlYk4Iu1K_CXhk8QhINCqcWRGslagQ_CWyuz7tj2JQ02XrJQEEsF8P9VpQIYZo5GA_InsjLiwn3Rw2rSFwB-f9UvPji57Z6km78QBkeiXZJk0UumBK7RZsEteEnFRleBcnOKlM0TbhebkriFTWlaArxd9tkbZnr1xU2nMVXHhLhzS3MOIz7PAtQLv2WKiSJil9ot6S9jqvQ_QBFzznHSseOBPnPdV_zwR01qpRxeBwcKXi4X5ck2V-10RHWAqDPJWtwHr_dvWAqpNSARbS7oQwJEmg9vM_g_z2lk6vZqhnhRa7x74iv-mIDeBXV2H_hpXR2BOZROMCao81gVb_PWx5XFe-kiJPwC_NBTE4kjrmOHdDAXd1WW1E3AmnA5yUOC775bpqrG6M-xOjCS3LAi23FLikdyeRx9u3SM2MzlctJUOslzZlT-uMg_oA-BawRylH5DS-IsCsqBJ1E2EOwCrIRqSD90eMDrt--HjsdhbeOL7qw2MfMJ-W28iHZBsI25hooPF4W5CdOV3cqTXwCqledtYFD762mbFaNQIqGpbjlMlJGUoQ-6462ihKI=&p=4&sk=&fvj=0'>DATA SCIENTIST</a>
# <a href = '/cmp/The-Home-Depot'>
#         Home Depot</a>
# <a href = '/cmp/The-Home-Depot/reviews'>
# 21,066 reviews</a>
# <a href = '/pagead/clk?mo=r&ad=-6NYlbfkN0Aqmv_5JD5v6gg1ICRL12VY6BolF0XAUkQtat1DEGOKAas7v4hqpX3lzUM4h7L4VGsyuyDvf1POStkSJgHsuP2fB8YliLIijj53wvHBII5P9eQQwhBoT2Vrz0Dv0LOR9cmhA2uclIYN05H0FXZOFBhD9nFyVh6o8Pj-jnxI3CbMISVeGeVDBCyxVR6yZuCFehgzktgysMGHUL-roVmwC2j3G80RFSqE-aBVW-JwUn0q6sLZozKRnBJJ4b5KYlJZmo1SII-gap5KxPAM8P9ibOzHhWGm1yjZNRBfSyc5I9IEqCnncYFpPOaRlb0RRWUq_Xvzpxcp1QFJJ7yPWOiIP7I5hO-tGTA_DvRw-uLskag6uqVcIlw3k5alpzn5GN8E0spNHKdz7vvWtgWtmld8vURbi_1dAAo3asIRod6Vk_18cR6MWQ9TQtrhZUsOogVf3BM9Ysnd2hqYSPUA6zwf4w9469LugJJXK9Y=&p=5&sk=&fvj=0'>Data Scientist</a>
# <a href = '/cmp/Cox-Automotive'>
#         Cox Automotive</a>
# <a href = '/cmp/Cox-Automotive/reviews'>
# 46 reviews</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=10'>2</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=20'>3</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=30'>4</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=40'>5</a>
# <a href = '/jobs?q=Data+Scientist&l=Atlanta%2C+GA&start=10&pp='>Next »</a>
# <a href = '/q-Accounting-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>accounting</a>
# <a href = '/q-Part-Time-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>part time</a>
# <a href = '/q-Clerical-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>clerical</a>
# <a href = '/q-Call-Center-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>call center</a>
# <a href = '/q-Construction-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>construction</a>
# <a href = '/q-Data-Entry-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>data entry</a>
# <a href = '/q-Graphic-Design-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>graphic design</a>
# <a href = '/q-Human-Resources-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>human resources</a>
# <a href = '/q-Insurance-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>insurance</a>
# <a href = '/q-Marketing-l-Atlanta,-GA-jobs.html?from=relatedQueries&rqf=1&parentQnorm=Data+Scientist'>marketing</a>
# <a href = '/forum/job/Statistician.html'>Statistician</a>
# <a href = '/forum/job/Quantitative-Analyst.html'>Quantitative Analyst</a>
# <a href = '/forum/loc/Atlanta-Georgia.html'>Atlanta, Georgia</a>
# <a href = '/salary?q1=Statistician&l1=Atlanta%2C+GA'>Statistician salary</a>
# <a href = '/salary?q1=Quantitative+Analyst&l1=Atlanta%2C+GA'>Quantitative Analyst salary</a>
# <a href = '/cmp/Cox-Automotive'>
#
# </a>
# <a href = '/cmp/Cox-Automotive'>
#             Cox Automotive</a>
# <a href = '/jobs?q=company%3A%22Cox+Automotive%22&l=Atlanta%2C+GA'>Jobs (105)</a>
# <a href = '/cmp/Cox-Automotive/reviews'>Reviews (46)</a>
# <a href = '/promo/prime'>Learn More</a>
# <a href = '/promo/gotajob'>Over 2.8 million stories shared</a>
# <a href = '/'>Jobs</a>
# <a href = '/Best-Places-to-Work'>Browse Companies</a>
# <a href = '/salary'>Salaries</a>
# <a href = '/jobtrends'>Trends</a>
# <a href = '/forum'>Forums</a>
# <a href = '/find-jobs.jsp'>Browse Jobs</a>
# <a href = '/tools/jobseeker/'>Tools</a>
# <a href = 'http://www.indeed.jobs'>Work at Indeed</a>
# <a href = '/publisher'>API</a>
# <a href = '/intl/en/about.html'>About</a>
# <a href = 'https://indeed.zendesk.com/hc/en-us'>Help Center</a>
# <a href = '/legal'>Cookies, Privacy and Terms</a>
