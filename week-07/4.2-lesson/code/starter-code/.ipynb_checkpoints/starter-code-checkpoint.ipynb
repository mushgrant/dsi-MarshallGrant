# %%
import pandas as pd
import numpy as np

from sklearn.cluster import DBSCAN, KMeans
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# ## 1. Load the data

# %%
arpt = pd.read_csv('../../assets/datasets/airport_operations.csv')
arpt.sample(10)
# Out:
#     airport  year  departures for metric computation  \
# 261     HNL  2012                              88261
# 538     ONT  2014                              32791
# 59      BHM  2008                              34605
# 214     DTW  2009                             211239
# 278     HPN  2007                              35911
# 571     PBI  2014                              37466
# 251     GYY  2013                                519
# 464     MKE  2006                              87040
# 646     RFD  2004                               1946
# 808     TPA  2004                             100556
#
#      arrivals for metric computation  percent on-time gate departures  \
# 261                            88228                           0.8791
# 538                            32476                           0.7161
# 59                             34766                           0.7715
# 214                           210518                           0.8311
# 278                            36118                           0.5299
# 571                            36904                           0.6586
# 251                              540                           0.5511
# 464                            86797                           0.7625
# 646                             1935                           0.6912
# 808                           100312                           0.8245
#
#      percent on-time airport departures  percent on-time gate arrivals  \
# 261                              0.8523                         0.8629
# 538                              0.6824                         0.7347
# 59                               0.7406                         0.7289
# 214                              0.7286                         0.8224
# 278                              0.4612                         0.5136
# 571                              0.6297                         0.6439
# 251                              0.5472                         0.6704
# 464                              0.7353                         0.7278
# 646                              0.6598                         0.7907
# 808                              0.8023                         0.7921
#
#      average_gate_departure_delay  average_taxi_out_time  \
# 261                          7.32                  13.00
# 538                         16.92                  10.79
# 59                          13.82                  11.94
# 214                          9.85                  20.08
# 278                         25.84                  16.01
# 571                         18.58                  13.11
# 251                         23.26                  11.29
# 464                         13.46                  13.10
# 646                         13.20                   7.04
# 808                          9.85                  11.88
#
#      average taxi out delay  average airport departure delay  \
# 261                    2.24                             8.67
# 538                    2.65                            19.09
# 59                     2.88                            15.82
# 214                    6.06                            14.68
# 278                    5.23                            30.62
# 571                    2.21                            20.42
# 251                    0.24                            23.91
# 464                    2.30                            15.02
# 646                    1.78                            14.50
# 808                    2.39                            11.53
#
#      average airborne delay  average taxi in delay  average block delay  \
# 261                    1.49                   1.32                 3.22
# 538                    1.47                   0.56                 2.10
# 59                     2.14                   0.65                 3.00
# 214                    4.24                   2.55                 3.27
# 278                    4.67                   3.07                 6.97
# 571                    2.93                   0.78                 5.03
# 251                    2.64                   0.00                 2.89
# 464                    1.75                   0.92                 3.78
# 646                    2.27                   0.81                 3.60
# 808                    2.24                   0.70                 3.10
#
#      average gate arrival delay
# 261                        8.00
# 538                       14.01
# 59                        15.37
# 214                       10.62
# 278                       27.16
# 571                       20.17
# 251                       15.17
# 464                       14.85
# 646                       11.39
# 808                       11.30

# %% [markdown]
# ## 2. Format and graph the data

# %% [markdown]
# #### 2.1 Plot the data

# %%
sns.heatmap(arpt.corr() )

# %% [markdown]
# #### 2.2 Select columns of interest and standardize the data

# %%
StandardScaler()

# %% [markdown]
# ## 3. DBSCAN

# %% [markdown]
# #### 3.1 Setup the DBSCAN from scikit

# %%
db = DBSCAN(eps=0.5, min_samples = 5).fit(X)

# %% [markdown]
# #### 3.2 Calculate the Labels

# %%
labels = db.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-72bff6da7a9a> in <module>()
# ----> 1 db_labels = db.core_sample_indices
#
# NameError: name 'db' is not defined

# %% [markdown]
# #### 3.3 Calculate the Core Samples

# %%
samples = db.core_sample_indices

# %%
print "core samples:\n", samples 
print "labels:\n", labels

# %%
core_samples2 = np.zeros_like(labels, dtype = bool)
core_samples2[db.core_sample_indices_] = True

# %% [markdown]
# #### 3.4 Plot the resulting clusters

# %% [markdown]
# Now, repeat the above steps for various levels of minimum points and epsilon and see how that affects the results of the DBSCAN algorithm

# %% [markdown]
# #### 3.5 Perform a K-means Clustering for comparison

# %%
KMeans(n_clusters=)

# %% [markdown]
# #### 3.6 Plot the resulting clusters

# %% [markdown]
# **Hint**: Display the results by cluster color and plot the centroids over the original plot for clarity

# %% [markdown]
# *Average airborne delay* and *on time gate arrivals*

# %% [markdown]
# *average taxi out time* and *average airport departure delay*
