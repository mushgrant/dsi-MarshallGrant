# %%
import pandas as pd

# %% [markdown]
# # created a csv with textedit by converting to plain text (VIEW)

# %%
dframe = pd.read_csv("datasets/udemytest.csv", )

# %%
dframe
# Out:
#    q  r  s  t   apple
# 0  2  3  4  5    pear
# 1  a  s  d  f  rabbit
# 2  5  2  5  7     dog

# %%
dframe = pd.read_csv("datasets/udemytest.csv",header=None )

# %%
dframe
# Out:
#    0  1  2  3       4
# 0  q  r  s  t   apple
# 1  2  3  4  5    pear
# 2  a  s  d  f  rabbit
# 3  5  2  5  7     dog

# %%
dframe = pd.read_table("datasets/udemytest.csv", sep = ',',header=None )
# can use table if we have a diff seperator besides a comma

# %%
dframe
# Out:
#    0  1  2  3       4
# 0  q  r  s  t   apple
# 1  2  3  4  5    pear
# 2  a  s  d  f  rabbit
# 3  5  2  5  7     dog

# %%
dframe_short = pd.read_csv("datasets/udemytest.csv",header = None, nrows=2)

# %% [markdown]
# We can set the # of rows we want to import with the data

# %%
dframe_short
# Out:
#    0  1  2  3      4
# 0  q  r  s  t  apple
# 1  2  3  4  5   pear

# %%
#creating a csv saves to where the workbook is open from 
dframe.to_csv('mytextdata_out.csv')

# %%
#we use sys to show what the execution would be without actually doing it
import sys

# %%
dframe.to_csv(sys.stdout)
# Out:
# ,0,1,2,3,4
# 0,q,r,s,t,apple
# 1,2,3,4,5,pear
# 2,a,s,d,f,rabbit
# 3,5,2,5,7,dog

# %%
dframe.to_csv(sys.stdout, sep='_')
# Out:
# _0_1_2_3_4
# 0_q_r_s_t_apple
# 1_2_3_4_5_pear
# 2_a_s_d_f_rabbit
# 3_5_2_5_7_dog

# %%
from pandas import Series, DataFrame

# %%
from pandas import read_html

# %%
url = 'http://www.fdic.gov/bank/individual/failed/banklist.html'

# %%
dframe_list = pd.io.html.read_html(url)
print dframe_list
# Out:
# [                                  Bank Name             City  ST   CERT  \
# 0                               Allied Bank         Mulberry  AR     91
# 1              The Woodbury Banking Company         Woodbury  GA  11297
# 2                    First CornerStone Bank  King of Prussia  PA  35312
# 3                        Trust Company Bank          Memphis  TN   9956
# 4                North Milwaukee State Bank        Milwaukee  WI  20364
# 5                    Hometown National Bank         Longview  WA  35156
# 6                       The Bank of Georgia   Peachtree City  GA  35259
# 7                              Premier Bank           Denver  CO  34112
# 8                            Edgebrook Bank          Chicago  IL  57772
# 9                    Doral Bank  En Espanol         San Juan  PR  32102
# 10        Capitol City Bank & Trust Company          Atlanta  GA  33938
# 11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
dframe = dframe_list[0]
dframe
# Out:
#                                   Bank Name             City  ST   CERT  \
# 0                               Allied Bank         Mulberry  AR     91
# 1              The Woodbury Banking Company         Woodbury  GA  11297
# 2                    First CornerStone Bank  King of Prussia  PA  35312
# 3                        Trust Company Bank          Memphis  TN   9956
# 4                North Milwaukee State Bank        Milwaukee  WI  20364
# 5                    Hometown National Bank         Longview  WA  35156
# 6                       The Bank of Georgia   Peachtree City  GA  35259
# 7                              Premier Bank           Denver  CO  34112
# 8                            Edgebrook Bank          Chicago  IL  57772
# 9                    Doral Bank  En Espanol         San Juan  PR  32102
# 10        Capitol City Bank & Trust Company          Atlanta  GA  33938
# 11                  Highland Community Bank          Chicago  IL  20290
# ...

# %%
dframe.columns.values
# Out:
# array([u'Bank Name', u'City', u'ST', u'CERT', u'Acquiring Institution',
#        u'Closing Date', u'Updated Date'], dtype=object)

# %%
url2 = "http://www.espn.com/mlb/stats/batting"

# %%
mlb = pd.io.html.read_html(url2)

# %%
mld2 = mlb[0]

# %%
mld2
# Out:
#                   0                 1        2    3    4    5    6    7    8   \
# 0   Sortable Batting               NaN      NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1                 RK            PLAYER     TEAM   AB    R    H   2B   3B   HR
# 2                  1       DJ LeMahieu      COL  552  104  192   32    8   11
# 3                  2     Daniel Murphy      WSH  531   88  184   47    5   25
# 4                  3       Jose Altuve      HOU  640  108  216   42    5   24
# 5                  4        Joey Votto      CIN  556  101  181   34    2   29
# 6                  5  Charlie Blackmon      COL  578  111  187   35    5   29
# 7                  6       Jean Segura      ARI  637  102  203   41    7   20
# 8                  7      Mookie Betts      BOS  672  122  214   42    5   31
# 9                  8    Dustin Pedroia      BOS  633  105  201   36    1   15
# 10                 9    Miguel Cabrera      DET  595   92  188   31    1   38
# ...

# %% [markdown]
# # importing an xls file using pandas

# %%
xlsfile = pd.ExcelFile('Workbook1.xlsx')

# %%
dframe = xlsfile.parse('Sheet1')

# %%
dframe
# Out:
#    this is a test  Unnamed: 1  Unnamed: 2
# 0              23        6678         456
# 1             234         678         456
# 2             234           7         345
# 3              34          56         234
# 4               5         456        4365
